# %% [markdown]
# <div style="text-align: center;">
# <h1>The University of North Carolina at Chapel Hill</h1>
# <h1>Comp 521 Files and Databases - Fall 2019</h1>
# <h1 style="font-size: 250%;">Problem Set #1</h1>
# <h1 style="font-size: 200%;">Version 1.0</h1>
# <h1>Issued Tuesday 09/03/2019; Due Tuesday 09/17/2019</h1>
# </div>
#
# **Homework Information:** The answer cells in this notebook contain metadata that enable it to be automatically parsed. Thus, you must enter your answers *only* into the cells provided. Do not delete any answer cell and/or add a new one to replace it. If you do so by accident, download a new copy of the problem set's notebook and transfer your answers into it. You can introduce new 'coding' cells in an effort to test approaches to problems, however, these introduced cells will not be considered when grading.
#
# Finally, some of the problems are probably too long to be done the night before the due date, so plan accordingly. Late problem sets will be accepted, but your lowest problem-set grade will be dropped. Feel free to get help from others, but the work you submit in should be your own.

# %%
# Do not make any edits in this cell!
class Student:
    first = "Adam"
    last = "Alston"
    onyen = "aalston9"
    pid = "730015776"

# %% [markdown]
# The following questions relate to the design of a schema for an NFL database.
# Your primary data is provided in two downloadable text files. The first, is called <a href="https://csbio.unc.edu/mcmillan/Media/NFLrosters.csv">"NFLrosters.csv"</a> and has the following format:
# <pre><code style="font-size:80%;">
# team,year,jersey,name,position,height,weight,games,starts,college,dob,draftYear,draftRound,draftOrder,draftTeam
# carolina-panthers,2003,52,Brian Allen,LB,6-3,215,14,4,Florida State,--,--,--,--,--
# carolina-panthers,2003,80,Eugene Baker,WR,6-2,183,1,0,Kent State,1976-03-18,1999,5,164,atlanta-falcons
# carolina-panthers,2003,47,Marco Battaglia,TE,6-3,250,2,0,Rutgers,1973-01-25,1996,2,39,cincinnati-bengals
# carolina-panthers,2003,--,Nathan Black,WR,6-0,190,0,0,Northwestern State,1978-06-20,--,--,--,--
# carolina-panthers,2003,28,Colin Branch,DB,6-0,203,16,0,Stanford,1980-03-02,2003,4,119,carolina-panthers
# carolina-panthers,2003,79,Doug Brzezinski,OG,6-4,305,1,0,Boston College,1976-03-11,1999,3,64,philadelphia-eagles
# carolina-panthers,2003,99,Brentson Buckner,DT,6-2,305,12,12,Clemson,1971-09-30,1994,2,50,pittsburgh-steelers
# carolina-panthers,2003,98,Shane Burton,DE,6-6,305,16,4,Tennessee,1974-01-18,1996,5,150,miami-dolphins
# carolina-panthers,2003,59,Mike Caldwell,LB,6-2,200,9,0,Middle Tennessee State,--,--,--,--,--
# carolina-panthers,2003,50,Vinny Ciurciu,LB,6-0,235,2,0,Boston College,1980-05-02,--,--,--,--
# carolina-panthers,2003,40,Jarrod Cooper,DB,6-0,210,12,0,Kansas State,1978-03-31,2001,5,143,carolina-panthers
#                  .
#                  .
#                  .
#     </code></pre>
# A roster is a list of the players on a given team in a given year.
#        Each row also includes information about the player, such as their jersey number, position,
#        and the number of games that they played in and started in the given year.
#        It also includes information related the college they attended and their draft order if applicable.
# The second file is called <a href="https://csbio.unc.edu/mcmillan/Media/NFLgames.csv">"NFLgames.csv"</a> and has the following format:
# <pre><code style="font-size:80%;">
# season,week,date,visitor,vScore,home,hScore,notes
# 2018,1,2018-09-06,atlanta-falcons,12,philadelphia-eagles,18,
# 2018,1,2018-09-09,buffalo-bills,3,baltimore-ravens,47,
# 2018,1,2018-09-09,cincinnati-bengals,34,indianapolis-colts,23,
# 2018,1,2018-09-09,pittsburgh-steelers,21,cleveland-browns,21,
# 2018,1,2018-09-09,houston-texans,20,new-england-patriots,27,
# 2018,1,2018-09-09,jacksonville-jaguars,20,new-york-giants,15,
# 2018,1,2018-09-09,tennessee-titans,20,miami-dolphins,27,
# 2018,1,2018-09-09,san-francisco-49ers,16,minnesota-vikings,24,
# 2018,1,2018-09-09,tampa-bay-buccaneers,48,new-orleans-saints,40,
# 2018,1,2018-09-09,kansas-city-chiefs,38,los-angeles-chargers,28,
#                  .
#                  .
#                  .
#     </code></pre>
# It provides the final score for every game played during the season.
#     The visiting and home teams names are also provided.
#     Regular season games are denoted by their week number, whereas the 'week' indicates
#     the playoff round in the post-season.
#     Special notes are included for some games.

# %% [markdown]
# Assume a database with tables for the following entities: <b>Player</b>, <b>Team</b>, <b>Game</b>, and <b>Draft</b>.
# You can assume that each player is assigned a <em>player id</em> (PID) as a primary key.
# Likewise, each team is assigned a <em>team id</em> (TID) as a primary key.
# The primary key of the Game relation is a composite of the season, week, and hometeam's TID.
# The primary key of the Draft relation is a composite of the draftYear and draftOrder.

# %% [markdown]
# ---
# **Problem 1:** What columns from NFLroster.csv and other Entities would you include in the Player table?

# %% [raw]
# name,height,weight,college,dob

# %% [markdown]
# ---
# **Problem 2:** How many distinct entries would be populated in the Player relation using NFLroster.csv?

# %% [raw]
# 3
# # name,college,dob

# %% [markdown]
# ---
# **Problem 3:** What columns, either in part or in full, from NFLroster.csv would you include in the Team table? Consider that teams have historically changed both locations and mascots.

# %% [raw]
# team,year

# %% [markdown]
# ---
# **Problem 4:** What component of the Game table's composite key is a foreign key from another table? What does this imply with regard to inserting new Game table rows?

# %% [raw]
# tid, it implies that the you need information about from the team table

# %% [markdown]
# ---
# **Problem 5:** In how many regular season games did the home team win?

# %% [raw]
# 5907
# # games where the home score was greater than the visitor score

# %%
import pandas as pd

dataframe = pd.read_csv("NFLgames.csv")
dataframe
# Out:
#        season                     week        date               visitor  \
# 0        1978                        1  1978-09-02       new-york-giants
# 1        1978                        1  1978-09-03     green-bay-packers
# 2        1978                        1  1978-09-03        houston-oilers
# 3        1978                        1  1978-09-03    kansas-city-chiefs
# 4        1978                        1  1978-09-03      los-angeles-rams
# 5        1978                        1  1978-09-03        miami-dolphins
# 6        1978                        1  1978-09-03     minnesota-vikings
# 7        1978                        1  1978-09-03   pittsburgh-steelers
# 8        1978                        1  1978-09-03   st.-louis-cardinals
# 9        1978                        1  1978-09-03   san-francisco-49ers
# 10       1978                        1  1978-09-03   washington-redskins
# 11       1978                        1  1978-09-03       oakland-raiders
# 12       1978                        1  1978-09-03    san-diego-chargers
# 13       1978                        1  1978-09-04       baltimore-colts
# 14       1978                        2  1978-09-09         detroit-lions
# 15       1978                        2  1978-09-10    cincinnati-bengals
# 16       1978                        2  1978-09-10        dallas-cowboys
# 17       1978                        2  1978-09-10        houston-oilers
# 18       1978                        2  1978-09-10  new-england-patriots
# 19       1978                        2  1978-09-10    new-orleans-saints
# 20       1978                        2  1978-09-10   philadelphia-eagles
# 21       1978                        2  1978-09-10      seattle-seahawks
# 22       1978                        2  1978-09-10       atlanta-falcons
# 23       1978                        2  1978-09-10         chicago-bears
# 24       1978                        2  1978-09-10        miami-dolphins
# 25       1978                        2  1978-09-10         new-york-jets
# 26       1978                        2  1978-09-10       oakland-raiders
# 27       1978                        2  1978-09-11        denver-broncos
# 28       1978                        3  1978-09-17         chicago-bears
# 29       1978                        3  1978-09-17      cleveland-browns
# ...       ...                      ...         ...                   ...
# 10155    2018                       16  2018-12-23   pittsburgh-steelers
# 10156    2018                       16  2018-12-23    kansas-city-chiefs
# 10157    2018                       16  2018-12-24        denver-broncos
# 10158    2018                       17  2018-12-30       atlanta-falcons
# 10159    2018                       17  2018-12-30        miami-dolphins
# 10160    2018                       17  2018-12-30     carolina-panthers
# 10161    2018                       17  2018-12-30        dallas-cowboys
# 10162    2018                       17  2018-12-30         detroit-lions
# 10163    2018                       17  2018-12-30  jacksonville-jaguars
# 10164    2018                       17  2018-12-30         new-york-jets
# 10165    2018                       17  2018-12-30     arizona-cardinals
# 10166    2018                       17  2018-12-30      cleveland-browns
# 10167    2018                       17  2018-12-30         chicago-bears
# 10168    2018                       17  2018-12-30    cincinnati-bengals
# 10169    2018                       17  2018-12-30  los-angeles-chargers
# 10170    2018                       17  2018-12-30       oakland-raiders
# 10171    2018                       17  2018-12-30   san-francisco-49ers
# 10172    2018                       17  2018-12-30   philadelphia-eagles
# 10173    2018                       17  2018-12-30    indianapolis-colts
# 10174    2018        Wild Card Playoff  2019-01-05    indianapolis-colts
# 10175    2018        Wild Card Playoff  2019-01-05      seattle-seahawks
# 10176    2018        Wild Card Playoff  2019-01-06  los-angeles-chargers
# 10177    2018        Wild Card Playoff  2019-01-06   philadelphia-eagles
# 10178    2018       Divisional Playoff  2019-01-12    indianapolis-colts
# 10179    2018       Divisional Playoff  2019-01-12        dallas-cowboys
# 10180    2018       Divisional Playoff  2019-01-13  los-angeles-chargers
# 10181    2018       Divisional Playoff  2019-01-13   philadelphia-eagles
# 10182    2018  Conference Championship  2019-01-20      los-angeles-rams
# 10183    2018  Conference Championship  2019-01-20  new-england-patriots
# 10184    2018               Super Bowl  2019-02-03  new-england-patriots
#
#        vScore                  home  hScore notes
# 0          19  tampa-bay-buccaneers      13   NaN
# 1          13         detroit-lions       7   NaN
# 2          14       atlanta-falcons      20   NaN
# 3          24    cincinnati-bengals      23   NaN
# 4          16   philadelphia-eagles      14   NaN
# 5          20         new-york-jets      33   NaN
# 6          24    new-orleans-saints      31   NaN
# 7          28         buffalo-bills      17   NaN
# 8          10         chicago-bears      17   NaN
# 9           7      cleveland-browns      24   NaN
# 10         16  new-england-patriots      14   NaN
# 11          6        denver-broncos      14   NaN
# 12         24      seattle-seahawks      20   NaN
# 13          0        dallas-cowboys      38   NaN
# 14         15  tampa-bay-buccaneers       7   NaN
# 15         10      cleveland-browns      13    OT
# 16         34       new-york-giants      24   NaN
# 17         20    kansas-city-chiefs      17   NaN
# 18         16   st.-louis-cardinals       6   NaN
# 19         17     green-bay-packers      28   NaN
# 20         30   washington-redskins      35   NaN
# 21         10   pittsburgh-steelers      21   NaN
# 22          0      los-angeles-rams      10   NaN
# 23         16   san-francisco-49ers      13   NaN
# 24         42       baltimore-colts       0   NaN
# 25         21         buffalo-bills      20   NaN
# 26         21    san-diego-chargers      20   NaN
# 27          9     minnesota-vikings      12    OT
# 28         19         detroit-lions       0   NaN
# 29         24       atlanta-falcons      16   NaN
# ...       ...                   ...     ...   ...
# 10155      28    new-orleans-saints      31   NaN
# 10156      31      seattle-seahawks      38   NaN
# 10157      14       oakland-raiders      27   NaN
# 10158      34  tampa-bay-buccaneers      32   NaN
# 10159      17         buffalo-bills      42   NaN
# 10160      33    new-orleans-saints      14   NaN
# 10161      36       new-york-giants      35   NaN
# 10162      31     green-bay-packers       0   NaN
# 10163       3        houston-texans      20   NaN
# 10164       3  new-england-patriots      38   NaN
# 10165      24      seattle-seahawks      27   NaN
# 10166      24      baltimore-ravens      26   NaN
# 10167      24     minnesota-vikings      10   NaN
# 10168      13   pittsburgh-steelers      16   NaN
# 10169      23        denver-broncos       9   NaN
# 10170       3    kansas-city-chiefs      35   NaN
# 10171      32      los-angeles-rams      48   NaN
# 10172      24   washington-redskins       0   NaN
# 10173      33      tennessee-titans      17   NaN
# 10174      21        houston-texans       7   NaN
# 10175      22        dallas-cowboys      24   NaN
# 10176      23      baltimore-ravens      17   NaN
# 10177      16         chicago-bears      15   NaN
# 10178      13    kansas-city-chiefs      31   NaN
# 10179      22      los-angeles-rams      30   NaN
# 10180      28  new-england-patriots      41   NaN
# 10181      14    new-orleans-saints      20   NaN
# 10182      26    new-orleans-saints      23    OT
# 10183      37    kansas-city-chiefs      31    OT
# 10184      13      los-angeles-rams       3   NaN
#
# [10185 rows x 8 columns]

# %%
homeWins = 0
for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
 if (row["hScore"] > row["vScore"]):
     homeWins += 1
print(homeWins)
# Out:
# 5907

# %% [markdown]
# ---
# **Problem 6:** How many entries in NFLroster.csv differ from another entry by only the year?

# %% [raw]
# 18960
# # calculated rows in csv and then subtracted duplicate rows of every column except for year

# %%
import pandas as pd

dataframe = pd.read_csv("NFLrosters.csv")
dataframe
# Out:
#                       team  year jersey               name position height  \
# 0      san-francisco-49ers  1960     --         Dave Baker       DB    6-0
# 1      san-francisco-49ers  1960     --       Bruce Bosley       OG    6-2
# 2      san-francisco-49ers  1960     --        John Brodie       QB    6-1
# 3      san-francisco-49ers  1960     --        Monte Clark       OT    6-6
# 4      san-francisco-49ers  1960     --       Dan Colchico       DE     --
# 5      san-francisco-49ers  1960     --       Clyde Conner       OE    6-2
# 6      san-francisco-49ers  1960     --       Ted Connolly       OG    6-3
# 7      san-francisco-49ers  1960     --        Tommy Davis        K    6-0
# 8      san-francisco-49ers  1960     --         Eddie Dove       DB    6-2
# 9      san-francisco-49ers  1960     --       Bob Harrison       LB    6-2
# 10     san-francisco-49ers  1960     --     Matt Hazeltine       LB    6-1
# 11     san-francisco-49ers  1960     --           Ed Henke       DE    6-3
# 12     san-francisco-49ers  1960     --      Gorden Kelley       LB    6-3
# 13     san-francisco-49ers  1960     --    Charlie Krueger       DT    6-4
# 14     san-francisco-49ers  1960     --        Lenny Lyles       DB    6-2
# 15     san-francisco-49ers  1960     --         Dee Mackey       TE    6-5
# 16     san-francisco-49ers  1960     --         Mike Magac       OG    6-3
# 17     san-francisco-49ers  1960     --     Hugh McElhenny       RB    6-1
# 18     san-francisco-49ers  1960     --      Jerry Mertens       DB    6-0
# 19     san-francisco-49ers  1960     --        Frank Morze        C    6-4
# 20     san-francisco-49ers  1960     --      Leo Nomellini       DT    6-3
# 21     san-francisco-49ers  1960     --         Ray Norton       RB    6-2
# 22     san-francisco-49ers  1960     --     Clancy Osborne       LB    6-3
# 23     san-francisco-49ers  1960     --         R.C. Owens       OE    6-3
# 24     san-francisco-49ers  1960     --          Joe Perry       RB    6-0
# 25     san-francisco-49ers  1960     --       Jimmy Ridlon       DB    6-1
# 26     san-francisco-49ers  1960     --       C.R. Roberts       RB    6-3
# 27     san-francisco-49ers  1960     --          Len Rohde       OT    6-4
# 28     san-francisco-49ers  1960     --         Karl Rubke       LB    6-4
# 29     san-francisco-49ers  1960     --      Henry Schmidt       DT    6-4
# ...                    ...   ...    ...                ...      ...    ...
# 98422    minnesota-vikings  2019     89       David Morgan       TE    6-4
# 98423    minnesota-vikings  2019     72       Storm Norton       OT    6-7
# 98424    minnesota-vikings  2019     75      Brian O'Neill       OT    6-7
# 98425    minnesota-vikings  2019     95    Ifeadi Odenigbo       DE    6-3
# 98426    minnesota-vikings  2019     60      Tito Odenigbo       DT    6-3
# 98427    minnesota-vikings  2019     71        Riley Reiff       OT    6-6
# 98428    minnesota-vikings  2019     29      Xavier Rhodes       DB    6-1
# 98429    minnesota-vikings  2019     82       Kyle Rudolph       TE    6-6
# 98430    minnesota-vikings  2019     62  Anree Saint-Amour       DE    6-3
# 98431    minnesota-vikings  2019     73          Dru Samia       OG    6-5
# 98432    minnesota-vikings  2019     79      Karter Schult       DL    6-3
# 98433    minnesota-vikings  2019      1        Kyle Sloter       QB    6-5
# 98434    minnesota-vikings  2019     59      Cameron Smith       LB    6-2
# 98435    minnesota-vikings  2019     37       Derron Smith       DB   5-10
# 98436    minnesota-vikings  2019     22     Harrison Smith       DB    6-2
# 98437    minnesota-vikings  2019     84          Irv Smith       TE    6-2
# 98438    minnesota-vikings  2019     93     Shamar Stephen       DT    6-5
# 98439    minnesota-vikings  2019     19       Adam Thielen       WR    6-2
# 98440    minnesota-vikings  2019     34        Duke Thomas       DB   5-10
# 98441    minnesota-vikings  2019     11   Laquon Treadwell       WR    6-2
# 98442    minnesota-vikings  2019     74    Olisaemeka Udoh       OT    6-5
# 98443    minnesota-vikings  2019      7       Kaare Vedvik        P    6-3
# 98444    minnesota-vikings  2019     96        Armon Watts       DT    6-5
# 98445    minnesota-vikings  2019     26        Trae Waynes       DB    6-0
# 98446    minnesota-vikings  2019     91  Stephen Weatherly       LB    6-5
# 98447    minnesota-vikings  2019     35     Isaiah Wharton       DB    6-1
# 98448    minnesota-vikings  2019      6          Matt Wile        P    6-2
# 98449    minnesota-vikings  2019     50        Eric Wilson       LB    6-1
# 98450    minnesota-vikings  2019     79       Nate Wozniak       TE   6-10
# 98451    minnesota-vikings  2019     15    Brandon Zylstra       WR    6-2
#
#       weight games starts              college         dob draftYear  \
# 0        192    --     --             Oklahoma  1937-07-30      1959
# 1        241    --     --        West Virginia  1933-11-05      1956
# 2        198    --     --             Stanford  1935-08-14      1957
# 3        265    --     --  Southern California  1937-01-24      1959
# 4         --    --     --       San Jose State          --        --
# 5        193    --     --              Pacific  1933-05-18        --
# 6        240    --     --                Tulsa  1931-12-05      1954
# 7        215    --     --      Louisiana State  1934-10-13      1957
# 8        181    --     --             Colorado  1937-04-04      1959
# 9        225    --     --             Oklahoma  1937-08-08      1959
# 10       220    --     --           California  1933-08-02      1955
# 11       227    --     --  Southern California  1927-12-13      1949
# 12       231    --     --              Georgia  1938-06-11        --
# 13       256    --     --            Texas A&M  1937-01-28      1958
# 14       202    --     --           Louisville  1936-01-26      1958
# 15       235    --     --   Texas A&M-Commerce  1934-10-16      1958
# 16       240    --     --             Missouri  1938-05-25      1960
# 17       195    --     --           Washington  1928-12-31      1952
# 18       184    --     --                Drake  1934-11-12      1958
# 19       270    --     --       Boston College  1933-03-21      1955
# 20       259    --     --            Minnesota  1924-06-19      1950
# 21       184    --     --       San Jose State  1937-09-22      1960
# 22       218    --     --        Arizona State  1934-11-23      1957
# 23       197    --     --     College of Idaho  1934-11-12      1956
# 24       200    --     --      Compton CC (CA)  1927-01-22        --
# 25       181    --     --             Syracuse  1934-07-11      1957
# 26       202    --     --  Southern California  1936-02-29      1958
# 27       247    --     --           Utah State  1938-04-16      1960
# 28       240    --     --  Southern California  1935-12-06      1957
# 29       254    --     --         Trinity (TX)  1935-09-28      1958
# ...      ...   ...    ...                  ...         ...       ...
# 98422    265     0      0    Texas-San Antonio  1993-05-19      2016
# 98423    317     0      0               Toledo  1994-05-16        --
# 98424    297     0      0           Pittsburgh  1995-09-15      2018
# 98425    258     0      0         Northwestern  1994-04-08      2017
# 98426    300     0      0                Miami          --        --
# 98427    305     0      0                 Iowa  1988-12-01      2012
# 98428    218     0      0        Florida State  1990-06-19      2013
# 98429    265     0      0           Notre Dame  1989-11-09      2011
# 98430    245     0      0         Georgia Tech          --        --
# 98431    305     0      0             Oklahoma          --      2019
# 98432    260     0      0        Northern Iowa  1993-12-21        --
# 98433    218     0      0    Northern Colorado  1994-02-07        --
# 98434    238     0      0  Southern California          --      2019
# 98435    200     0      0         Fresno State  1992-02-04      2015
# 98436    214     0      0           Notre Dame  1989-02-02      2012
# 98437    242     0      0              Alabama  1971-10-13      2019
# 98438    309     0      0          Connecticut  1991-02-25      2014
# 98439    200     0      0        Mankato State  1990-08-22        --
# 98440    192     0      0                Texas  1994-05-21        --
# 98441    215     0      0          Mississippi  1995-06-14      2016
# 98442    323     0      0                 Elon          --      2019
# 98443    210     0      0             Marshall  1994-03-16        --
# 98444    300     0      0             Arkansas          --      2019
# 98445    190     0      0       Michigan State  1992-07-25      2015
# 98446    265     0      0           Vanderbilt  1994-03-19      2016
# 98447    205     0      0              Rutgers          --        --
# 98448    225     0      0             Michigan  1992-06-20        --
# 98449    230     0      0           Cincinnati  1994-09-26        --
# 98450    280     0      0            Minnesota  1994-08-30        --
# 98451    215     0      0   Concordia-Moorhead  1993-03-25        --
#
#       draftRound draftOrder            draftTeam
# 0              1          5  san-francisco-49ers
# 1              2         15  san-francisco-49ers
# 2              1          3  san-francisco-49ers
# 3              4         41  san-francisco-49ers
# 4             --         --                   --
# 5             --         --                   --
# 6              9        107  san-francisco-49ers
# 7             11        128  san-francisco-49ers
# 8              3         29  san-francisco-49ers
# 9              2         17  san-francisco-49ers
# 10             4         45  san-francisco-49ers
# 11            13        128  washington-redskins
# 12            --         --                   --
# 13             1          9  san-francisco-49ers
# 14             1         11      baltimore-colts
# 15            24        287  san-francisco-49ers
# 16             2         16  san-francisco-49ers
# 17             1          9  san-francisco-49ers
# 18            20        239  san-francisco-49ers
# 19             2         21  san-francisco-49ers
# 20             1         11  san-francisco-49ers
# 21             4         46  san-francisco-49ers
# 22            27        315     los-angeles-rams
# 23            14        160  san-francisco-49ers
# 24            --         --                   --
# 25             4         39  san-francisco-49ers
# 26            14        166      new-york-giants
# 27             5         59  san-francisco-49ers
# 28             5         56  san-francisco-49ers
# 29             6         71  san-francisco-49ers
# ...          ...        ...                  ...
# 98422          6        188    minnesota-vikings
# 98423         --         --                   --
# 98424          2         62    minnesota-vikings
# 98425          7        220    minnesota-vikings
# 98426         --         --                   --
# 98427          1         23        detroit-lions
# 98428          1         25    minnesota-vikings
# 98429          2         43    minnesota-vikings
# 98430         --         --                   --
# 98431          4        114    minnesota-vikings
# 98432         --         --                   --
# 98433         --         --                   --
# 98434          5        162    minnesota-vikings
# 98435          6        197   cincinnati-bengals
# 98436          1         29    minnesota-vikings
# 98437          2         50    minnesota-vikings
# 98438          7        220    minnesota-vikings
# 98439         --         --                   --
# 98440         --         --                   --
# 98441          1         23    minnesota-vikings
# 98442          6        193    minnesota-vikings
# 98443         --         --                   --
# 98444          6        190    minnesota-vikings
# 98445          1         11    minnesota-vikings
# 98446          7        227    minnesota-vikings
# 98447         --         --                   --
# 98448         --         --                   --
# 98449         --         --                   --
# 98450         --         --                   --
# 98451         --         --                   --
#
# [98452 rows x 15 columns]

# %%
entries = dataframe.drop_duplicates(subset=['team','position','jersey','position','height','weight','games','starts','college','dob','draftYear','draftRound','draftOrder','draftTeam'])
print len(dataframe)
print len(entries)
differByOnlyYear = len(dataframe) - len(entries)
print differByOnlyYear
# Out:
# 98452
# 79492
# 18960

# %% [markdown]
# ---
# The next series of question consider the two relations <b>PlayedFor</b> and <b>LocatedAt</b>.
# PlayedFor has a primary key composed of a season-year, a PID, and a TID, as well as other attributes.
# LocatedAt has a primary key composed of a season-year, and a TID, as well as other attributes.

# %% [markdown]
# ---
# **Problem 7:** How would you modify or extend the LocatedAt and/or Team tables to allow Teams to change mascots?

# %% [raw]
# I would modify the Team table to add a Mascot field. Mascot should be independent of location.
# ALTER TABLE Team
# ADD Mascot TEXT;

# %% [markdown]
# ---
# **Problem 8:** Based on the data provided, estimate the size of the PlayedFor table. Explain your estimate.

# %% [raw]
# 98452
# # The PlayedFor tabel should have an entry for every record in the NFLrosters file

# %%
import pandas as pd

dataframe = pd.read_csv("NFLrosters.csv")
dataframe
# Out:
#                       team  year jersey               name position height  \
# 0      san-francisco-49ers  1960     --         Dave Baker       DB    6-0
# 1      san-francisco-49ers  1960     --       Bruce Bosley       OG    6-2
# 2      san-francisco-49ers  1960     --        John Brodie       QB    6-1
# 3      san-francisco-49ers  1960     --        Monte Clark       OT    6-6
# 4      san-francisco-49ers  1960     --       Dan Colchico       DE     --
# 5      san-francisco-49ers  1960     --       Clyde Conner       OE    6-2
# 6      san-francisco-49ers  1960     --       Ted Connolly       OG    6-3
# 7      san-francisco-49ers  1960     --        Tommy Davis        K    6-0
# 8      san-francisco-49ers  1960     --         Eddie Dove       DB    6-2
# 9      san-francisco-49ers  1960     --       Bob Harrison       LB    6-2
# 10     san-francisco-49ers  1960     --     Matt Hazeltine       LB    6-1
# 11     san-francisco-49ers  1960     --           Ed Henke       DE    6-3
# 12     san-francisco-49ers  1960     --      Gorden Kelley       LB    6-3
# 13     san-francisco-49ers  1960     --    Charlie Krueger       DT    6-4
# 14     san-francisco-49ers  1960     --        Lenny Lyles       DB    6-2
# 15     san-francisco-49ers  1960     --         Dee Mackey       TE    6-5
# 16     san-francisco-49ers  1960     --         Mike Magac       OG    6-3
# 17     san-francisco-49ers  1960     --     Hugh McElhenny       RB    6-1
# 18     san-francisco-49ers  1960     --      Jerry Mertens       DB    6-0
# 19     san-francisco-49ers  1960     --        Frank Morze        C    6-4
# 20     san-francisco-49ers  1960     --      Leo Nomellini       DT    6-3
# 21     san-francisco-49ers  1960     --         Ray Norton       RB    6-2
# 22     san-francisco-49ers  1960     --     Clancy Osborne       LB    6-3
# 23     san-francisco-49ers  1960     --         R.C. Owens       OE    6-3
# 24     san-francisco-49ers  1960     --          Joe Perry       RB    6-0
# 25     san-francisco-49ers  1960     --       Jimmy Ridlon       DB    6-1
# 26     san-francisco-49ers  1960     --       C.R. Roberts       RB    6-3
# 27     san-francisco-49ers  1960     --          Len Rohde       OT    6-4
# 28     san-francisco-49ers  1960     --         Karl Rubke       LB    6-4
# 29     san-francisco-49ers  1960     --      Henry Schmidt       DT    6-4
# ...                    ...   ...    ...                ...      ...    ...
# 98422    minnesota-vikings  2019     89       David Morgan       TE    6-4
# 98423    minnesota-vikings  2019     72       Storm Norton       OT    6-7
# 98424    minnesota-vikings  2019     75      Brian O'Neill       OT    6-7
# 98425    minnesota-vikings  2019     95    Ifeadi Odenigbo       DE    6-3
# 98426    minnesota-vikings  2019     60      Tito Odenigbo       DT    6-3
# 98427    minnesota-vikings  2019     71        Riley Reiff       OT    6-6
# 98428    minnesota-vikings  2019     29      Xavier Rhodes       DB    6-1
# 98429    minnesota-vikings  2019     82       Kyle Rudolph       TE    6-6
# 98430    minnesota-vikings  2019     62  Anree Saint-Amour       DE    6-3
# 98431    minnesota-vikings  2019     73          Dru Samia       OG    6-5
# 98432    minnesota-vikings  2019     79      Karter Schult       DL    6-3
# 98433    minnesota-vikings  2019      1        Kyle Sloter       QB    6-5
# 98434    minnesota-vikings  2019     59      Cameron Smith       LB    6-2
# 98435    minnesota-vikings  2019     37       Derron Smith       DB   5-10
# 98436    minnesota-vikings  2019     22     Harrison Smith       DB    6-2
# 98437    minnesota-vikings  2019     84          Irv Smith       TE    6-2
# 98438    minnesota-vikings  2019     93     Shamar Stephen       DT    6-5
# 98439    minnesota-vikings  2019     19       Adam Thielen       WR    6-2
# 98440    minnesota-vikings  2019     34        Duke Thomas       DB   5-10
# 98441    minnesota-vikings  2019     11   Laquon Treadwell       WR    6-2
# 98442    minnesota-vikings  2019     74    Olisaemeka Udoh       OT    6-5
# 98443    minnesota-vikings  2019      7       Kaare Vedvik        P    6-3
# 98444    minnesota-vikings  2019     96        Armon Watts       DT    6-5
# 98445    minnesota-vikings  2019     26        Trae Waynes       DB    6-0
# 98446    minnesota-vikings  2019     91  Stephen Weatherly       LB    6-5
# 98447    minnesota-vikings  2019     35     Isaiah Wharton       DB    6-1
# 98448    minnesota-vikings  2019      6          Matt Wile        P    6-2
# 98449    minnesota-vikings  2019     50        Eric Wilson       LB    6-1
# 98450    minnesota-vikings  2019     79       Nate Wozniak       TE   6-10
# 98451    minnesota-vikings  2019     15    Brandon Zylstra       WR    6-2
#
#       weight games starts              college         dob draftYear  \
# 0        192    --     --             Oklahoma  1937-07-30      1959
# 1        241    --     --        West Virginia  1933-11-05      1956
# 2        198    --     --             Stanford  1935-08-14      1957
# 3        265    --     --  Southern California  1937-01-24      1959
# 4         --    --     --       San Jose State          --        --
# 5        193    --     --              Pacific  1933-05-18        --
# 6        240    --     --                Tulsa  1931-12-05      1954
# 7        215    --     --      Louisiana State  1934-10-13      1957
# 8        181    --     --             Colorado  1937-04-04      1959
# 9        225    --     --             Oklahoma  1937-08-08      1959
# 10       220    --     --           California  1933-08-02      1955
# 11       227    --     --  Southern California  1927-12-13      1949
# 12       231    --     --              Georgia  1938-06-11        --
# 13       256    --     --            Texas A&M  1937-01-28      1958
# 14       202    --     --           Louisville  1936-01-26      1958
# 15       235    --     --   Texas A&M-Commerce  1934-10-16      1958
# 16       240    --     --             Missouri  1938-05-25      1960
# 17       195    --     --           Washington  1928-12-31      1952
# 18       184    --     --                Drake  1934-11-12      1958
# 19       270    --     --       Boston College  1933-03-21      1955
# 20       259    --     --            Minnesota  1924-06-19      1950
# 21       184    --     --       San Jose State  1937-09-22      1960
# 22       218    --     --        Arizona State  1934-11-23      1957
# 23       197    --     --     College of Idaho  1934-11-12      1956
# 24       200    --     --      Compton CC (CA)  1927-01-22        --
# 25       181    --     --             Syracuse  1934-07-11      1957
# 26       202    --     --  Southern California  1936-02-29      1958
# 27       247    --     --           Utah State  1938-04-16      1960
# 28       240    --     --  Southern California  1935-12-06      1957
# 29       254    --     --         Trinity (TX)  1935-09-28      1958
# ...      ...   ...    ...                  ...         ...       ...
# 98422    265     0      0    Texas-San Antonio  1993-05-19      2016
# 98423    317     0      0               Toledo  1994-05-16        --
# 98424    297     0      0           Pittsburgh  1995-09-15      2018
# 98425    258     0      0         Northwestern  1994-04-08      2017
# 98426    300     0      0                Miami          --        --
# 98427    305     0      0                 Iowa  1988-12-01      2012
# 98428    218     0      0        Florida State  1990-06-19      2013
# 98429    265     0      0           Notre Dame  1989-11-09      2011
# 98430    245     0      0         Georgia Tech          --        --
# 98431    305     0      0             Oklahoma          --      2019
# 98432    260     0      0        Northern Iowa  1993-12-21        --
# 98433    218     0      0    Northern Colorado  1994-02-07        --
# 98434    238     0      0  Southern California          --      2019
# 98435    200     0      0         Fresno State  1992-02-04      2015
# 98436    214     0      0           Notre Dame  1989-02-02      2012
# 98437    242     0      0              Alabama  1971-10-13      2019
# 98438    309     0      0          Connecticut  1991-02-25      2014
# 98439    200     0      0        Mankato State  1990-08-22        --
# 98440    192     0      0                Texas  1994-05-21        --
# 98441    215     0      0          Mississippi  1995-06-14      2016
# 98442    323     0      0                 Elon          --      2019
# 98443    210     0      0             Marshall  1994-03-16        --
# 98444    300     0      0             Arkansas          --      2019
# 98445    190     0      0       Michigan State  1992-07-25      2015
# 98446    265     0      0           Vanderbilt  1994-03-19      2016
# 98447    205     0      0              Rutgers          --        --
# 98448    225     0      0             Michigan  1992-06-20        --
# 98449    230     0      0           Cincinnati  1994-09-26        --
# 98450    280     0      0            Minnesota  1994-08-30        --
# 98451    215     0      0   Concordia-Moorhead  1993-03-25        --
#
#       draftRound draftOrder            draftTeam
# 0              1          5  san-francisco-49ers
# 1              2         15  san-francisco-49ers
# 2              1          3  san-francisco-49ers
# 3              4         41  san-francisco-49ers
# 4             --         --                   --
# 5             --         --                   --
# 6              9        107  san-francisco-49ers
# 7             11        128  san-francisco-49ers
# 8              3         29  san-francisco-49ers
# 9              2         17  san-francisco-49ers
# 10             4         45  san-francisco-49ers
# 11            13        128  washington-redskins
# 12            --         --                   --
# 13             1          9  san-francisco-49ers
# 14             1         11      baltimore-colts
# 15            24        287  san-francisco-49ers
# 16             2         16  san-francisco-49ers
# 17             1          9  san-francisco-49ers
# 18            20        239  san-francisco-49ers
# 19             2         21  san-francisco-49ers
# 20             1         11  san-francisco-49ers
# 21             4         46  san-francisco-49ers
# 22            27        315     los-angeles-rams
# 23            14        160  san-francisco-49ers
# 24            --         --                   --
# 25             4         39  san-francisco-49ers
# 26            14        166      new-york-giants
# 27             5         59  san-francisco-49ers
# 28             5         56  san-francisco-49ers
# 29             6         71  san-francisco-49ers
# ...          ...        ...                  ...
# 98422          6        188    minnesota-vikings
# 98423         --         --                   --
# 98424          2         62    minnesota-vikings
# 98425          7        220    minnesota-vikings
# 98426         --         --                   --
# 98427          1         23        detroit-lions
# 98428          1         25    minnesota-vikings
# 98429          2         43    minnesota-vikings
# 98430         --         --                   --
# 98431          4        114    minnesota-vikings
# 98432         --         --                   --
# 98433         --         --                   --
# 98434          5        162    minnesota-vikings
# 98435          6        197   cincinnati-bengals
# 98436          1         29    minnesota-vikings
# 98437          2         50    minnesota-vikings
# 98438          7        220    minnesota-vikings
# 98439         --         --                   --
# 98440         --         --                   --
# 98441          1         23    minnesota-vikings
# 98442          6        193    minnesota-vikings
# 98443         --         --                   --
# 98444          6        190    minnesota-vikings
# 98445          1         11    minnesota-vikings
# 98446          7        227    minnesota-vikings
# 98447         --         --                   --
# 98448         --         --                   --
# 98449         --         --                   --
# 98450         --         --                   --
# 98451         --         --                   --
#
# [98452 rows x 15 columns]

# %%
print len(dataframe)
# Out:
# 98452

# %% [markdown]
# ---
# **Problem 9:** Based on the data provided, estimate the size of the LocatedAt table. Explain your estimate.

# %% [raw]
# 1230
# # 32 teams, 41 years, every team should have an entry for every year
# # estimate=32*41

# %%
import pandas as pd

dataframe = pd.read_csv("NFLgames.csv")
dataframe
# Out:
#        season                     week        date               visitor  \
# 0        1978                        1  1978-09-02       new-york-giants
# 1        1978                        1  1978-09-03     green-bay-packers
# 2        1978                        1  1978-09-03        houston-oilers
# 3        1978                        1  1978-09-03    kansas-city-chiefs
# 4        1978                        1  1978-09-03      los-angeles-rams
# 5        1978                        1  1978-09-03        miami-dolphins
# 6        1978                        1  1978-09-03     minnesota-vikings
# 7        1978                        1  1978-09-03   pittsburgh-steelers
# 8        1978                        1  1978-09-03   st.-louis-cardinals
# 9        1978                        1  1978-09-03   san-francisco-49ers
# 10       1978                        1  1978-09-03   washington-redskins
# 11       1978                        1  1978-09-03       oakland-raiders
# 12       1978                        1  1978-09-03    san-diego-chargers
# 13       1978                        1  1978-09-04       baltimore-colts
# 14       1978                        2  1978-09-09         detroit-lions
# 15       1978                        2  1978-09-10    cincinnati-bengals
# 16       1978                        2  1978-09-10        dallas-cowboys
# 17       1978                        2  1978-09-10        houston-oilers
# 18       1978                        2  1978-09-10  new-england-patriots
# 19       1978                        2  1978-09-10    new-orleans-saints
# 20       1978                        2  1978-09-10   philadelphia-eagles
# 21       1978                        2  1978-09-10      seattle-seahawks
# 22       1978                        2  1978-09-10       atlanta-falcons
# 23       1978                        2  1978-09-10         chicago-bears
# 24       1978                        2  1978-09-10        miami-dolphins
# 25       1978                        2  1978-09-10         new-york-jets
# 26       1978                        2  1978-09-10       oakland-raiders
# 27       1978                        2  1978-09-11        denver-broncos
# 28       1978                        3  1978-09-17         chicago-bears
# 29       1978                        3  1978-09-17      cleveland-browns
# ...       ...                      ...         ...                   ...
# 10155    2018                       16  2018-12-23   pittsburgh-steelers
# 10156    2018                       16  2018-12-23    kansas-city-chiefs
# 10157    2018                       16  2018-12-24        denver-broncos
# 10158    2018                       17  2018-12-30       atlanta-falcons
# 10159    2018                       17  2018-12-30        miami-dolphins
# 10160    2018                       17  2018-12-30     carolina-panthers
# 10161    2018                       17  2018-12-30        dallas-cowboys
# 10162    2018                       17  2018-12-30         detroit-lions
# 10163    2018                       17  2018-12-30  jacksonville-jaguars
# 10164    2018                       17  2018-12-30         new-york-jets
# 10165    2018                       17  2018-12-30     arizona-cardinals
# 10166    2018                       17  2018-12-30      cleveland-browns
# 10167    2018                       17  2018-12-30         chicago-bears
# 10168    2018                       17  2018-12-30    cincinnati-bengals
# 10169    2018                       17  2018-12-30  los-angeles-chargers
# 10170    2018                       17  2018-12-30       oakland-raiders
# 10171    2018                       17  2018-12-30   san-francisco-49ers
# 10172    2018                       17  2018-12-30   philadelphia-eagles
# 10173    2018                       17  2018-12-30    indianapolis-colts
# 10174    2018        Wild Card Playoff  2019-01-05    indianapolis-colts
# 10175    2018        Wild Card Playoff  2019-01-05      seattle-seahawks
# 10176    2018        Wild Card Playoff  2019-01-06  los-angeles-chargers
# 10177    2018        Wild Card Playoff  2019-01-06   philadelphia-eagles
# 10178    2018       Divisional Playoff  2019-01-12    indianapolis-colts
# 10179    2018       Divisional Playoff  2019-01-12        dallas-cowboys
# 10180    2018       Divisional Playoff  2019-01-13  los-angeles-chargers
# 10181    2018       Divisional Playoff  2019-01-13   philadelphia-eagles
# 10182    2018  Conference Championship  2019-01-20      los-angeles-rams
# 10183    2018  Conference Championship  2019-01-20  new-england-patriots
# 10184    2018               Super Bowl  2019-02-03  new-england-patriots
#
#        vScore                  home  hScore notes
# 0          19  tampa-bay-buccaneers      13   NaN
# 1          13         detroit-lions       7   NaN
# 2          14       atlanta-falcons      20   NaN
# 3          24    cincinnati-bengals      23   NaN
# 4          16   philadelphia-eagles      14   NaN
# 5          20         new-york-jets      33   NaN
# 6          24    new-orleans-saints      31   NaN
# 7          28         buffalo-bills      17   NaN
# 8          10         chicago-bears      17   NaN
# 9           7      cleveland-browns      24   NaN
# 10         16  new-england-patriots      14   NaN
# 11          6        denver-broncos      14   NaN
# 12         24      seattle-seahawks      20   NaN
# 13          0        dallas-cowboys      38   NaN
# 14         15  tampa-bay-buccaneers       7   NaN
# 15         10      cleveland-browns      13    OT
# 16         34       new-york-giants      24   NaN
# 17         20    kansas-city-chiefs      17   NaN
# 18         16   st.-louis-cardinals       6   NaN
# 19         17     green-bay-packers      28   NaN
# 20         30   washington-redskins      35   NaN
# 21         10   pittsburgh-steelers      21   NaN
# 22          0      los-angeles-rams      10   NaN
# 23         16   san-francisco-49ers      13   NaN
# 24         42       baltimore-colts       0   NaN
# 25         21         buffalo-bills      20   NaN
# 26         21    san-diego-chargers      20   NaN
# 27          9     minnesota-vikings      12    OT
# 28         19         detroit-lions       0   NaN
# 29         24       atlanta-falcons      16   NaN
# ...       ...                   ...     ...   ...
# 10155      28    new-orleans-saints      31   NaN
# 10156      31      seattle-seahawks      38   NaN
# 10157      14       oakland-raiders      27   NaN
# 10158      34  tampa-bay-buccaneers      32   NaN
# 10159      17         buffalo-bills      42   NaN
# 10160      33    new-orleans-saints      14   NaN
# 10161      36       new-york-giants      35   NaN
# 10162      31     green-bay-packers       0   NaN
# 10163       3        houston-texans      20   NaN
# 10164       3  new-england-patriots      38   NaN
# 10165      24      seattle-seahawks      27   NaN
# 10166      24      baltimore-ravens      26   NaN
# 10167      24     minnesota-vikings      10   NaN
# 10168      13   pittsburgh-steelers      16   NaN
# 10169      23        denver-broncos       9   NaN
# 10170       3    kansas-city-chiefs      35   NaN
# 10171      32      los-angeles-rams      48   NaN
# 10172      24   washington-redskins       0   NaN
# 10173      33      tennessee-titans      17   NaN
# 10174      21        houston-texans       7   NaN
# 10175      22        dallas-cowboys      24   NaN
# 10176      23      baltimore-ravens      17   NaN
# 10177      16         chicago-bears      15   NaN
# 10178      13    kansas-city-chiefs      31   NaN
# 10179      22      los-angeles-rams      30   NaN
# 10180      28  new-england-patriots      41   NaN
# 10181      14    new-orleans-saints      20   NaN
# 10182      26    new-orleans-saints      23    OT
# 10183      37    kansas-city-chiefs      31    OT
# 10184      13      los-angeles-rams       3   NaN
#
# [10185 rows x 8 columns]

# %%
homeCnt = dataframe.home.value_counts()
print homeCnt
print len(homeCnt)
# there are 32 teams
# Out:
# new-england-patriots    357
# san-francisco-49ers     353
# pittsburgh-steelers     352
# denver-broncos          350
# philadelphia-eagles     347
# dallas-cowboys          346
# green-bay-packers       343
# miami-dolphins          341
# seattle-seahawks        340
# chicago-bears           340
# new-york-giants         340
# buffalo-bills           337
# minnesota-vikings       337
# washington-redskins     337
# atlanta-falcons         336
# cincinnati-bengals      335
# new-orleans-saints      335
# kansas-city-chiefs      333
# tampa-bay-buccaneers    332
# new-york-jets           329
# detroit-lions           326
# san-diego-chargers      318
# cleveland-browns        306
# indianapolis-colts      293
# oakland-raiders         230
# arizona-cardinals       205
# carolina-panthers       199
# jacksonville-jaguars    196
# baltimore-ravens        190
# st.-louis-rams          173
# tennessee-titans        165
# los-angeles-rams        163
# houston-oilers          153
# houston-texans          141
# los-angeles-raiders     108
# st.-louis-cardinals      75
# phoenix-cardinals        48
# baltimore-colts          44
# los-angeles-chargers     16
# tennessee-oilers         16
# Name: home, dtype: int64
# 40

# %%
seasonCnt = dataframe.season.value_counts()
print len(seasonCnt)
# there are 41 rows which means there are 41 years
# Out:
# 41

# %%
playedForEst = len(homeCnt) * len(seasonCnt)
# Every team should have an entry for every year
print playedForEst
# Out:
# 1640

# %% [markdown]
# ---
# **Problem 10:** Budding DBA Lee Hart has suggested placing the "position" field in the PlayedFor table rather than the Player table. What are the advantages or disadvantages of this modification?

# %% [raw]
# Advantages: Depending on which team the player is playing for, they can change positions
# Disadvantages: The position is not distinctly atttached to the player but instead the player's stint with a team
#
# # Something that I did consider was that players sometimes play more than one position at the same time. Neither before or after the modification could this property be specified in either table. So I think that is something to consider moving forward.

# %% [markdown]
# ---
# **Problem 11:** Budding DBA Lee Hart has suggested placing the "jersey" field in the PlayedFor table rather than the Player table. What are the advantages or disadvantages of this modification?

# %% [raw]
# Advantages: When a player switches teams, they do not always keep the same number so this would allow for the player to change numbers if they weren't allowed to before the modication
# Disadvantages: Sometimes multiple people on the same team have the same number. You could no longer use the jersey number as an identifier of the player. You would need more information to go along with it.

# %% [markdown]
# ---
# **Problem 12:** A roster player might become injured and spend part of a season in a special injured reserve list. How would you modify the given schema to capture this relation?

# %% [raw]
# I would add a column to the PlayedFor table caller ir (injured reserve) and update that column accordingly.
# ALTER TABLE PlayedFor
# ADD COLUMN ir: TEXT

# %% [markdown]
# ...
# For the next series of questions enter valid SQL statements.
# In some cases you will need to reference PIDs and TIDs using the helper functions
# getPID(name,dob,college) and getTID(teamName,year) respectively.

# %% [markdown]
# ---
# **Problem 13:** Give the CREATE TABLE command for your implementation of the Team table. Include all primary and foriegn key declarions as well as any unique constraints.

# %% [raw]
# CREATE TABLE Team (
#     getTID(teamName,year) INTEGER,
#     name TEXT,
#     mascot TEXT,
#     PRIMARY KEY (tid,name),
#     FOREIGN KEY (year) REFERENCES PlayedFor(season-year)
# )

# %% [markdown]
# ---
# **Problem 14:** Give the CREATE TABLE command for your implementation of the Game table. Include all primary and foriegn key declarions as well as any unique constraints.

# %% [raw]
# CREATE TABLE Game (
#     season INTEGER,
#     week INTEGER,
#     getTID(teamName,year) INTEGER,
#     date DATE,
#     vtid INTEGER,
#     vscore INTEGER,
#     hscore INTEGER,
#     notes TEXT,
#     PRIMARY KEY(season,week,tid),
#     FOREIGN KEY (year) REFERENCES PlayedFor(season-year),
#     FOREIGN KEY (teamName) REFERENCES Team(name)
# )

# %% [markdown]
# ---
# **Problem 15:** Give the CREATE TABLE command for your implementation of the Draft table. Include all primary and foriegn key declarions as well as any unique constraints.

# %% [raw]
# CREATE TABLE Draft (
#     draftYear YEAR,
#     draftOrder INTEGER,
#     getPID(name,dob,college) INTEGER,
#     getTID(teamName,year) INTEGER,
#     PRIMARY KEY (draftYear, draftOrder),
#     FOREIGN KEY (teamName) REFERENCES Team(name),
#     FOREIGN KEY (year) REFERENCES PlayedFor(season-year),
#     FOREIGN KEY (name) REFERENCES Player(name),
#     FOREIGN KEY (dob) REFERENCES Player(dob),
#     FOREIGN KEY (college) REFERENCES Player(college)
# )

# %% [markdown]
# ---
# **Problem 16:** Give an INSERT command that adds 'Jacoby Brissett' to your Player table. Use actual data from NFLroster.csv.

# %% [raw]
# INSERT INTO Player
#     VALUES (PID,'Jacoby Brisett',6-4,231,'North Carolina State',1993-12-11)

# %%
import pandas as pd

dataframe = pd.read_csv("NFLrosters.csv")
dataframe
# Out:
#                       team  year jersey               name position height  \
# 0      san-francisco-49ers  1960     --         Dave Baker       DB    6-0
# 1      san-francisco-49ers  1960     --       Bruce Bosley       OG    6-2
# 2      san-francisco-49ers  1960     --        John Brodie       QB    6-1
# 3      san-francisco-49ers  1960     --        Monte Clark       OT    6-6
# 4      san-francisco-49ers  1960     --       Dan Colchico       DE     --
# 5      san-francisco-49ers  1960     --       Clyde Conner       OE    6-2
# 6      san-francisco-49ers  1960     --       Ted Connolly       OG    6-3
# 7      san-francisco-49ers  1960     --        Tommy Davis        K    6-0
# 8      san-francisco-49ers  1960     --         Eddie Dove       DB    6-2
# 9      san-francisco-49ers  1960     --       Bob Harrison       LB    6-2
# 10     san-francisco-49ers  1960     --     Matt Hazeltine       LB    6-1
# 11     san-francisco-49ers  1960     --           Ed Henke       DE    6-3
# 12     san-francisco-49ers  1960     --      Gorden Kelley       LB    6-3
# 13     san-francisco-49ers  1960     --    Charlie Krueger       DT    6-4
# 14     san-francisco-49ers  1960     --        Lenny Lyles       DB    6-2
# 15     san-francisco-49ers  1960     --         Dee Mackey       TE    6-5
# 16     san-francisco-49ers  1960     --         Mike Magac       OG    6-3
# 17     san-francisco-49ers  1960     --     Hugh McElhenny       RB    6-1
# 18     san-francisco-49ers  1960     --      Jerry Mertens       DB    6-0
# 19     san-francisco-49ers  1960     --        Frank Morze        C    6-4
# 20     san-francisco-49ers  1960     --      Leo Nomellini       DT    6-3
# 21     san-francisco-49ers  1960     --         Ray Norton       RB    6-2
# 22     san-francisco-49ers  1960     --     Clancy Osborne       LB    6-3
# 23     san-francisco-49ers  1960     --         R.C. Owens       OE    6-3
# 24     san-francisco-49ers  1960     --          Joe Perry       RB    6-0
# 25     san-francisco-49ers  1960     --       Jimmy Ridlon       DB    6-1
# 26     san-francisco-49ers  1960     --       C.R. Roberts       RB    6-3
# 27     san-francisco-49ers  1960     --          Len Rohde       OT    6-4
# 28     san-francisco-49ers  1960     --         Karl Rubke       LB    6-4
# 29     san-francisco-49ers  1960     --      Henry Schmidt       DT    6-4
# ...                    ...   ...    ...                ...      ...    ...
# 98422    minnesota-vikings  2019     89       David Morgan       TE    6-4
# 98423    minnesota-vikings  2019     72       Storm Norton       OT    6-7
# 98424    minnesota-vikings  2019     75      Brian O'Neill       OT    6-7
# 98425    minnesota-vikings  2019     95    Ifeadi Odenigbo       DE    6-3
# 98426    minnesota-vikings  2019     60      Tito Odenigbo       DT    6-3
# 98427    minnesota-vikings  2019     71        Riley Reiff       OT    6-6
# 98428    minnesota-vikings  2019     29      Xavier Rhodes       DB    6-1
# 98429    minnesota-vikings  2019     82       Kyle Rudolph       TE    6-6
# 98430    minnesota-vikings  2019     62  Anree Saint-Amour       DE    6-3
# 98431    minnesota-vikings  2019     73          Dru Samia       OG    6-5
# 98432    minnesota-vikings  2019     79      Karter Schult       DL    6-3
# 98433    minnesota-vikings  2019      1        Kyle Sloter       QB    6-5
# 98434    minnesota-vikings  2019     59      Cameron Smith       LB    6-2
# 98435    minnesota-vikings  2019     37       Derron Smith       DB   5-10
# 98436    minnesota-vikings  2019     22     Harrison Smith       DB    6-2
# 98437    minnesota-vikings  2019     84          Irv Smith       TE    6-2
# 98438    minnesota-vikings  2019     93     Shamar Stephen       DT    6-5
# 98439    minnesota-vikings  2019     19       Adam Thielen       WR    6-2
# 98440    minnesota-vikings  2019     34        Duke Thomas       DB   5-10
# 98441    minnesota-vikings  2019     11   Laquon Treadwell       WR    6-2
# 98442    minnesota-vikings  2019     74    Olisaemeka Udoh       OT    6-5
# 98443    minnesota-vikings  2019      7       Kaare Vedvik        P    6-3
# 98444    minnesota-vikings  2019     96        Armon Watts       DT    6-5
# 98445    minnesota-vikings  2019     26        Trae Waynes       DB    6-0
# 98446    minnesota-vikings  2019     91  Stephen Weatherly       LB    6-5
# 98447    minnesota-vikings  2019     35     Isaiah Wharton       DB    6-1
# 98448    minnesota-vikings  2019      6          Matt Wile        P    6-2
# 98449    minnesota-vikings  2019     50        Eric Wilson       LB    6-1
# 98450    minnesota-vikings  2019     79       Nate Wozniak       TE   6-10
# 98451    minnesota-vikings  2019     15    Brandon Zylstra       WR    6-2
#
#       weight games starts              college         dob draftYear  \
# 0        192    --     --             Oklahoma  1937-07-30      1959
# 1        241    --     --        West Virginia  1933-11-05      1956
# 2        198    --     --             Stanford  1935-08-14      1957
# 3        265    --     --  Southern California  1937-01-24      1959
# 4         --    --     --       San Jose State          --        --
# 5        193    --     --              Pacific  1933-05-18        --
# 6        240    --     --                Tulsa  1931-12-05      1954
# 7        215    --     --      Louisiana State  1934-10-13      1957
# 8        181    --     --             Colorado  1937-04-04      1959
# 9        225    --     --             Oklahoma  1937-08-08      1959
# 10       220    --     --           California  1933-08-02      1955
# 11       227    --     --  Southern California  1927-12-13      1949
# 12       231    --     --              Georgia  1938-06-11        --
# 13       256    --     --            Texas A&M  1937-01-28      1958
# 14       202    --     --           Louisville  1936-01-26      1958
# 15       235    --     --   Texas A&M-Commerce  1934-10-16      1958
# 16       240    --     --             Missouri  1938-05-25      1960
# 17       195    --     --           Washington  1928-12-31      1952
# 18       184    --     --                Drake  1934-11-12      1958
# 19       270    --     --       Boston College  1933-03-21      1955
# 20       259    --     --            Minnesota  1924-06-19      1950
# 21       184    --     --       San Jose State  1937-09-22      1960
# 22       218    --     --        Arizona State  1934-11-23      1957
# 23       197    --     --     College of Idaho  1934-11-12      1956
# 24       200    --     --      Compton CC (CA)  1927-01-22        --
# 25       181    --     --             Syracuse  1934-07-11      1957
# 26       202    --     --  Southern California  1936-02-29      1958
# 27       247    --     --           Utah State  1938-04-16      1960
# 28       240    --     --  Southern California  1935-12-06      1957
# 29       254    --     --         Trinity (TX)  1935-09-28      1958
# ...      ...   ...    ...                  ...         ...       ...
# 98422    265     0      0    Texas-San Antonio  1993-05-19      2016
# 98423    317     0      0               Toledo  1994-05-16        --
# 98424    297     0      0           Pittsburgh  1995-09-15      2018
# 98425    258     0      0         Northwestern  1994-04-08      2017
# 98426    300     0      0                Miami          --        --
# 98427    305     0      0                 Iowa  1988-12-01      2012
# 98428    218     0      0        Florida State  1990-06-19      2013
# 98429    265     0      0           Notre Dame  1989-11-09      2011
# 98430    245     0      0         Georgia Tech          --        --
# 98431    305     0      0             Oklahoma          --      2019
# 98432    260     0      0        Northern Iowa  1993-12-21        --
# 98433    218     0      0    Northern Colorado  1994-02-07        --
# 98434    238     0      0  Southern California          --      2019
# 98435    200     0      0         Fresno State  1992-02-04      2015
# 98436    214     0      0           Notre Dame  1989-02-02      2012
# 98437    242     0      0              Alabama  1971-10-13      2019
# 98438    309     0      0          Connecticut  1991-02-25      2014
# 98439    200     0      0        Mankato State  1990-08-22        --
# 98440    192     0      0                Texas  1994-05-21        --
# 98441    215     0      0          Mississippi  1995-06-14      2016
# 98442    323     0      0                 Elon          --      2019
# 98443    210     0      0             Marshall  1994-03-16        --
# 98444    300     0      0             Arkansas          --      2019
# 98445    190     0      0       Michigan State  1992-07-25      2015
# 98446    265     0      0           Vanderbilt  1994-03-19      2016
# 98447    205     0      0              Rutgers          --        --
# 98448    225     0      0             Michigan  1992-06-20        --
# 98449    230     0      0           Cincinnati  1994-09-26        --
# 98450    280     0      0            Minnesota  1994-08-30        --
# 98451    215     0      0   Concordia-Moorhead  1993-03-25        --
#
#       draftRound draftOrder            draftTeam
# 0              1          5  san-francisco-49ers
# 1              2         15  san-francisco-49ers
# 2              1          3  san-francisco-49ers
# 3              4         41  san-francisco-49ers
# 4             --         --                   --
# 5             --         --                   --
# 6              9        107  san-francisco-49ers
# 7             11        128  san-francisco-49ers
# 8              3         29  san-francisco-49ers
# 9              2         17  san-francisco-49ers
# 10             4         45  san-francisco-49ers
# 11            13        128  washington-redskins
# 12            --         --                   --
# 13             1          9  san-francisco-49ers
# 14             1         11      baltimore-colts
# 15            24        287  san-francisco-49ers
# 16             2         16  san-francisco-49ers
# 17             1          9  san-francisco-49ers
# 18            20        239  san-francisco-49ers
# 19             2         21  san-francisco-49ers
# 20             1         11  san-francisco-49ers
# 21             4         46  san-francisco-49ers
# 22            27        315     los-angeles-rams
# 23            14        160  san-francisco-49ers
# 24            --         --                   --
# 25             4         39  san-francisco-49ers
# 26            14        166      new-york-giants
# 27             5         59  san-francisco-49ers
# 28             5         56  san-francisco-49ers
# 29             6         71  san-francisco-49ers
# ...          ...        ...                  ...
# 98422          6        188    minnesota-vikings
# 98423         --         --                   --
# 98424          2         62    minnesota-vikings
# 98425          7        220    minnesota-vikings
# 98426         --         --                   --
# 98427          1         23        detroit-lions
# 98428          1         25    minnesota-vikings
# 98429          2         43    minnesota-vikings
# 98430         --         --                   --
# 98431          4        114    minnesota-vikings
# 98432         --         --                   --
# 98433         --         --                   --
# 98434          5        162    minnesota-vikings
# 98435          6        197   cincinnati-bengals
# 98436          1         29    minnesota-vikings
# 98437          2         50    minnesota-vikings
# 98438          7        220    minnesota-vikings
# 98439         --         --                   --
# 98440         --         --                   --
# 98441          1         23    minnesota-vikings
# 98442          6        193    minnesota-vikings
# 98443         --         --                   --
# 98444          6        190    minnesota-vikings
# 98445          1         11    minnesota-vikings
# 98446          7        227    minnesota-vikings
# 98447         --         --                   --
# 98448         --         --                   --
# 98449         --         --                   --
# 98450         --         --                   --
# 98451         --         --                   --
#
# [98452 rows x 15 columns]

# %%
for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
 if (row["name"] == "Jacoby Brissett"):
    print row
    break
# Out:
# team            indianapolis-colts
# year                          2017
# jersey                           7
# name               Jacoby Brissett
# position                        QB
# height                         6-4
# weight                         231
# games                           16
# starts                          15
# college       North Carolina State
# dob                     1993-12-11
# draftYear                     2016
# draftRound                       3
# draftOrder                      91
# draftTeam     new-england-patriots
# Name: 36032, dtype: object

# %% [markdown]
# ---
# **Problem 17:** Give INSERT commands that add 'Los Vegas Raiders' to your Team and LocatedAt tables. Assume that a TID is automatically created on any insert to the Team table.

# %% [raw]
# INSERT INTO Team
# VALUES (TID,'Los Vegas Raiders','Raiders')
# INSERT INTO LocatedAt
# VALUES (2020,TID)

# %%
import pandas as pd

dataframe = pd.read_csv("NFLrosters.csv")
dataframe
# Out:
#                       team  year jersey               name position height  \
# 0      san-francisco-49ers  1960     --         Dave Baker       DB    6-0
# 1      san-francisco-49ers  1960     --       Bruce Bosley       OG    6-2
# 2      san-francisco-49ers  1960     --        John Brodie       QB    6-1
# 3      san-francisco-49ers  1960     --        Monte Clark       OT    6-6
# 4      san-francisco-49ers  1960     --       Dan Colchico       DE     --
# 5      san-francisco-49ers  1960     --       Clyde Conner       OE    6-2
# 6      san-francisco-49ers  1960     --       Ted Connolly       OG    6-3
# 7      san-francisco-49ers  1960     --        Tommy Davis        K    6-0
# 8      san-francisco-49ers  1960     --         Eddie Dove       DB    6-2
# 9      san-francisco-49ers  1960     --       Bob Harrison       LB    6-2
# 10     san-francisco-49ers  1960     --     Matt Hazeltine       LB    6-1
# 11     san-francisco-49ers  1960     --           Ed Henke       DE    6-3
# 12     san-francisco-49ers  1960     --      Gorden Kelley       LB    6-3
# 13     san-francisco-49ers  1960     --    Charlie Krueger       DT    6-4
# 14     san-francisco-49ers  1960     --        Lenny Lyles       DB    6-2
# 15     san-francisco-49ers  1960     --         Dee Mackey       TE    6-5
# 16     san-francisco-49ers  1960     --         Mike Magac       OG    6-3
# 17     san-francisco-49ers  1960     --     Hugh McElhenny       RB    6-1
# 18     san-francisco-49ers  1960     --      Jerry Mertens       DB    6-0
# 19     san-francisco-49ers  1960     --        Frank Morze        C    6-4
# 20     san-francisco-49ers  1960     --      Leo Nomellini       DT    6-3
# 21     san-francisco-49ers  1960     --         Ray Norton       RB    6-2
# 22     san-francisco-49ers  1960     --     Clancy Osborne       LB    6-3
# 23     san-francisco-49ers  1960     --         R.C. Owens       OE    6-3
# 24     san-francisco-49ers  1960     --          Joe Perry       RB    6-0
# 25     san-francisco-49ers  1960     --       Jimmy Ridlon       DB    6-1
# 26     san-francisco-49ers  1960     --       C.R. Roberts       RB    6-3
# 27     san-francisco-49ers  1960     --          Len Rohde       OT    6-4
# 28     san-francisco-49ers  1960     --         Karl Rubke       LB    6-4
# 29     san-francisco-49ers  1960     --      Henry Schmidt       DT    6-4
# ...                    ...   ...    ...                ...      ...    ...
# 98422    minnesota-vikings  2019     89       David Morgan       TE    6-4
# 98423    minnesota-vikings  2019     72       Storm Norton       OT    6-7
# 98424    minnesota-vikings  2019     75      Brian O'Neill       OT    6-7
# 98425    minnesota-vikings  2019     95    Ifeadi Odenigbo       DE    6-3
# 98426    minnesota-vikings  2019     60      Tito Odenigbo       DT    6-3
# 98427    minnesota-vikings  2019     71        Riley Reiff       OT    6-6
# 98428    minnesota-vikings  2019     29      Xavier Rhodes       DB    6-1
# 98429    minnesota-vikings  2019     82       Kyle Rudolph       TE    6-6
# 98430    minnesota-vikings  2019     62  Anree Saint-Amour       DE    6-3
# 98431    minnesota-vikings  2019     73          Dru Samia       OG    6-5
# 98432    minnesota-vikings  2019     79      Karter Schult       DL    6-3
# 98433    minnesota-vikings  2019      1        Kyle Sloter       QB    6-5
# 98434    minnesota-vikings  2019     59      Cameron Smith       LB    6-2
# 98435    minnesota-vikings  2019     37       Derron Smith       DB   5-10
# 98436    minnesota-vikings  2019     22     Harrison Smith       DB    6-2
# 98437    minnesota-vikings  2019     84          Irv Smith       TE    6-2
# 98438    minnesota-vikings  2019     93     Shamar Stephen       DT    6-5
# 98439    minnesota-vikings  2019     19       Adam Thielen       WR    6-2
# 98440    minnesota-vikings  2019     34        Duke Thomas       DB   5-10
# 98441    minnesota-vikings  2019     11   Laquon Treadwell       WR    6-2
# 98442    minnesota-vikings  2019     74    Olisaemeka Udoh       OT    6-5
# 98443    minnesota-vikings  2019      7       Kaare Vedvik        P    6-3
# 98444    minnesota-vikings  2019     96        Armon Watts       DT    6-5
# 98445    minnesota-vikings  2019     26        Trae Waynes       DB    6-0
# 98446    minnesota-vikings  2019     91  Stephen Weatherly       LB    6-5
# 98447    minnesota-vikings  2019     35     Isaiah Wharton       DB    6-1
# 98448    minnesota-vikings  2019      6          Matt Wile        P    6-2
# 98449    minnesota-vikings  2019     50        Eric Wilson       LB    6-1
# 98450    minnesota-vikings  2019     79       Nate Wozniak       TE   6-10
# 98451    minnesota-vikings  2019     15    Brandon Zylstra       WR    6-2
#
#       weight games starts              college         dob draftYear  \
# 0        192    --     --             Oklahoma  1937-07-30      1959
# 1        241    --     --        West Virginia  1933-11-05      1956
# 2        198    --     --             Stanford  1935-08-14      1957
# 3        265    --     --  Southern California  1937-01-24      1959
# 4         --    --     --       San Jose State          --        --
# 5        193    --     --              Pacific  1933-05-18        --
# 6        240    --     --                Tulsa  1931-12-05      1954
# 7        215    --     --      Louisiana State  1934-10-13      1957
# 8        181    --     --             Colorado  1937-04-04      1959
# 9        225    --     --             Oklahoma  1937-08-08      1959
# 10       220    --     --           California  1933-08-02      1955
# 11       227    --     --  Southern California  1927-12-13      1949
# 12       231    --     --              Georgia  1938-06-11        --
# 13       256    --     --            Texas A&M  1937-01-28      1958
# 14       202    --     --           Louisville  1936-01-26      1958
# 15       235    --     --   Texas A&M-Commerce  1934-10-16      1958
# 16       240    --     --             Missouri  1938-05-25      1960
# 17       195    --     --           Washington  1928-12-31      1952
# 18       184    --     --                Drake  1934-11-12      1958
# 19       270    --     --       Boston College  1933-03-21      1955
# 20       259    --     --            Minnesota  1924-06-19      1950
# 21       184    --     --       San Jose State  1937-09-22      1960
# 22       218    --     --        Arizona State  1934-11-23      1957
# 23       197    --     --     College of Idaho  1934-11-12      1956
# 24       200    --     --      Compton CC (CA)  1927-01-22        --
# 25       181    --     --             Syracuse  1934-07-11      1957
# 26       202    --     --  Southern California  1936-02-29      1958
# 27       247    --     --           Utah State  1938-04-16      1960
# 28       240    --     --  Southern California  1935-12-06      1957
# 29       254    --     --         Trinity (TX)  1935-09-28      1958
# ...      ...   ...    ...                  ...         ...       ...
# 98422    265     0      0    Texas-San Antonio  1993-05-19      2016
# 98423    317     0      0               Toledo  1994-05-16        --
# 98424    297     0      0           Pittsburgh  1995-09-15      2018
# 98425    258     0      0         Northwestern  1994-04-08      2017
# 98426    300     0      0                Miami          --        --
# 98427    305     0      0                 Iowa  1988-12-01      2012
# 98428    218     0      0        Florida State  1990-06-19      2013
# 98429    265     0      0           Notre Dame  1989-11-09      2011
# 98430    245     0      0         Georgia Tech          --        --
# 98431    305     0      0             Oklahoma          --      2019
# 98432    260     0      0        Northern Iowa  1993-12-21        --
# 98433    218     0      0    Northern Colorado  1994-02-07        --
# 98434    238     0      0  Southern California          --      2019
# 98435    200     0      0         Fresno State  1992-02-04      2015
# 98436    214     0      0           Notre Dame  1989-02-02      2012
# 98437    242     0      0              Alabama  1971-10-13      2019
# 98438    309     0      0          Connecticut  1991-02-25      2014
# 98439    200     0      0        Mankato State  1990-08-22        --
# 98440    192     0      0                Texas  1994-05-21        --
# 98441    215     0      0          Mississippi  1995-06-14      2016
# 98442    323     0      0                 Elon          --      2019
# 98443    210     0      0             Marshall  1994-03-16        --
# 98444    300     0      0             Arkansas          --      2019
# 98445    190     0      0       Michigan State  1992-07-25      2015
# 98446    265     0      0           Vanderbilt  1994-03-19      2016
# 98447    205     0      0              Rutgers          --        --
# 98448    225     0      0             Michigan  1992-06-20        --
# 98449    230     0      0           Cincinnati  1994-09-26        --
# 98450    280     0      0            Minnesota  1994-08-30        --
# 98451    215     0      0   Concordia-Moorhead  1993-03-25        --
#
#       draftRound draftOrder            draftTeam
# 0              1          5  san-francisco-49ers
# 1              2         15  san-francisco-49ers
# 2              1          3  san-francisco-49ers
# 3              4         41  san-francisco-49ers
# 4             --         --                   --
# 5             --         --                   --
# 6              9        107  san-francisco-49ers
# 7             11        128  san-francisco-49ers
# 8              3         29  san-francisco-49ers
# 9              2         17  san-francisco-49ers
# 10             4         45  san-francisco-49ers
# 11            13        128  washington-redskins
# 12            --         --                   --
# 13             1          9  san-francisco-49ers
# 14             1         11      baltimore-colts
# 15            24        287  san-francisco-49ers
# 16             2         16  san-francisco-49ers
# 17             1          9  san-francisco-49ers
# 18            20        239  san-francisco-49ers
# 19             2         21  san-francisco-49ers
# 20             1         11  san-francisco-49ers
# 21             4         46  san-francisco-49ers
# 22            27        315     los-angeles-rams
# 23            14        160  san-francisco-49ers
# 24            --         --                   --
# 25             4         39  san-francisco-49ers
# 26            14        166      new-york-giants
# 27             5         59  san-francisco-49ers
# 28             5         56  san-francisco-49ers
# 29             6         71  san-francisco-49ers
# ...          ...        ...                  ...
# 98422          6        188    minnesota-vikings
# 98423         --         --                   --
# 98424          2         62    minnesota-vikings
# 98425          7        220    minnesota-vikings
# 98426         --         --                   --
# 98427          1         23        detroit-lions
# 98428          1         25    minnesota-vikings
# 98429          2         43    minnesota-vikings
# 98430         --         --                   --
# 98431          4        114    minnesota-vikings
# 98432         --         --                   --
# 98433         --         --                   --
# 98434          5        162    minnesota-vikings
# 98435          6        197   cincinnati-bengals
# 98436          1         29    minnesota-vikings
# 98437          2         50    minnesota-vikings
# 98438          7        220    minnesota-vikings
# 98439         --         --                   --
# 98440         --         --                   --
# 98441          1         23    minnesota-vikings
# 98442          6        193    minnesota-vikings
# 98443         --         --                   --
# 98444          6        190    minnesota-vikings
# 98445          1         11    minnesota-vikings
# 98446          7        227    minnesota-vikings
# 98447         --         --                   --
# 98448         --         --                   --
# 98449         --         --                   --
# 98450         --         --                   --
# 98451         --         --                   --
#
# [98452 rows x 15 columns]

# %%
for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
 if (row["team"] == "oakland-raiders"):
    print row
    break
# Out:
# team              oakland-raiders
# year                         1960
# jersey                         --
# name                Ray Armstrong
# position                       DT
# height                        6-1
# weight                        235
# games                          --
# starts                         --
# college           Texas Christian
# dob                    1937-10-06
# draftYear                    1960
# draftRound                     20
# draftOrder                    236
# draftTeam     philadelphia-eagles
# Name: 69782, dtype: object

# %% [markdown]
# ---
# **Problem 18:** Give INSERT commands that add 'Baltimore Colts' to your Team and LocatedAt tables. Assume that a TID is automatically created on any insert to the Team table.

# %% [raw]
# INSERT INTO Team
#     VALUES (TID, 'baltimore-colts','colts')
# INSERT INTO LocatedAt
#     VALUES (TID,1960,'Baltimore')

# %%
import pandas as pd

dataframe = pd.read_csv("NFLgames.csv")
dataframe
# Out:
#        season                     week        date               visitor  \
# 0        1978                        1  1978-09-02       new-york-giants
# 1        1978                        1  1978-09-03     green-bay-packers
# 2        1978                        1  1978-09-03        houston-oilers
# 3        1978                        1  1978-09-03    kansas-city-chiefs
# 4        1978                        1  1978-09-03      los-angeles-rams
# 5        1978                        1  1978-09-03        miami-dolphins
# 6        1978                        1  1978-09-03     minnesota-vikings
# 7        1978                        1  1978-09-03   pittsburgh-steelers
# 8        1978                        1  1978-09-03   st.-louis-cardinals
# 9        1978                        1  1978-09-03   san-francisco-49ers
# 10       1978                        1  1978-09-03   washington-redskins
# 11       1978                        1  1978-09-03       oakland-raiders
# 12       1978                        1  1978-09-03    san-diego-chargers
# 13       1978                        1  1978-09-04       baltimore-colts
# 14       1978                        2  1978-09-09         detroit-lions
# 15       1978                        2  1978-09-10    cincinnati-bengals
# 16       1978                        2  1978-09-10        dallas-cowboys
# 17       1978                        2  1978-09-10        houston-oilers
# 18       1978                        2  1978-09-10  new-england-patriots
# 19       1978                        2  1978-09-10    new-orleans-saints
# 20       1978                        2  1978-09-10   philadelphia-eagles
# 21       1978                        2  1978-09-10      seattle-seahawks
# 22       1978                        2  1978-09-10       atlanta-falcons
# 23       1978                        2  1978-09-10         chicago-bears
# 24       1978                        2  1978-09-10        miami-dolphins
# 25       1978                        2  1978-09-10         new-york-jets
# 26       1978                        2  1978-09-10       oakland-raiders
# 27       1978                        2  1978-09-11        denver-broncos
# 28       1978                        3  1978-09-17         chicago-bears
# 29       1978                        3  1978-09-17      cleveland-browns
# ...       ...                      ...         ...                   ...
# 10155    2018                       16  2018-12-23   pittsburgh-steelers
# 10156    2018                       16  2018-12-23    kansas-city-chiefs
# 10157    2018                       16  2018-12-24        denver-broncos
# 10158    2018                       17  2018-12-30       atlanta-falcons
# 10159    2018                       17  2018-12-30        miami-dolphins
# 10160    2018                       17  2018-12-30     carolina-panthers
# 10161    2018                       17  2018-12-30        dallas-cowboys
# 10162    2018                       17  2018-12-30         detroit-lions
# 10163    2018                       17  2018-12-30  jacksonville-jaguars
# 10164    2018                       17  2018-12-30         new-york-jets
# 10165    2018                       17  2018-12-30     arizona-cardinals
# 10166    2018                       17  2018-12-30      cleveland-browns
# 10167    2018                       17  2018-12-30         chicago-bears
# 10168    2018                       17  2018-12-30    cincinnati-bengals
# 10169    2018                       17  2018-12-30  los-angeles-chargers
# 10170    2018                       17  2018-12-30       oakland-raiders
# 10171    2018                       17  2018-12-30   san-francisco-49ers
# 10172    2018                       17  2018-12-30   philadelphia-eagles
# 10173    2018                       17  2018-12-30    indianapolis-colts
# 10174    2018        Wild Card Playoff  2019-01-05    indianapolis-colts
# 10175    2018        Wild Card Playoff  2019-01-05      seattle-seahawks
# 10176    2018        Wild Card Playoff  2019-01-06  los-angeles-chargers
# 10177    2018        Wild Card Playoff  2019-01-06   philadelphia-eagles
# 10178    2018       Divisional Playoff  2019-01-12    indianapolis-colts
# 10179    2018       Divisional Playoff  2019-01-12        dallas-cowboys
# 10180    2018       Divisional Playoff  2019-01-13  los-angeles-chargers
# 10181    2018       Divisional Playoff  2019-01-13   philadelphia-eagles
# 10182    2018  Conference Championship  2019-01-20      los-angeles-rams
# 10183    2018  Conference Championship  2019-01-20  new-england-patriots
# 10184    2018               Super Bowl  2019-02-03  new-england-patriots
#
#        vScore                  home  hScore notes
# 0          19  tampa-bay-buccaneers      13   NaN
# 1          13         detroit-lions       7   NaN
# 2          14       atlanta-falcons      20   NaN
# 3          24    cincinnati-bengals      23   NaN
# 4          16   philadelphia-eagles      14   NaN
# 5          20         new-york-jets      33   NaN
# 6          24    new-orleans-saints      31   NaN
# 7          28         buffalo-bills      17   NaN
# 8          10         chicago-bears      17   NaN
# 9           7      cleveland-browns      24   NaN
# 10         16  new-england-patriots      14   NaN
# 11          6        denver-broncos      14   NaN
# 12         24      seattle-seahawks      20   NaN
# 13          0        dallas-cowboys      38   NaN
# 14         15  tampa-bay-buccaneers       7   NaN
# 15         10      cleveland-browns      13    OT
# 16         34       new-york-giants      24   NaN
# 17         20    kansas-city-chiefs      17   NaN
# 18         16   st.-louis-cardinals       6   NaN
# 19         17     green-bay-packers      28   NaN
# 20         30   washington-redskins      35   NaN
# 21         10   pittsburgh-steelers      21   NaN
# 22          0      los-angeles-rams      10   NaN
# 23         16   san-francisco-49ers      13   NaN
# 24         42       baltimore-colts       0   NaN
# 25         21         buffalo-bills      20   NaN
# 26         21    san-diego-chargers      20   NaN
# 27          9     minnesota-vikings      12    OT
# 28         19         detroit-lions       0   NaN
# 29         24       atlanta-falcons      16   NaN
# ...       ...                   ...     ...   ...
# 10155      28    new-orleans-saints      31   NaN
# 10156      31      seattle-seahawks      38   NaN
# 10157      14       oakland-raiders      27   NaN
# 10158      34  tampa-bay-buccaneers      32   NaN
# 10159      17         buffalo-bills      42   NaN
# 10160      33    new-orleans-saints      14   NaN
# 10161      36       new-york-giants      35   NaN
# 10162      31     green-bay-packers       0   NaN
# 10163       3        houston-texans      20   NaN
# 10164       3  new-england-patriots      38   NaN
# 10165      24      seattle-seahawks      27   NaN
# 10166      24      baltimore-ravens      26   NaN
# 10167      24     minnesota-vikings      10   NaN
# 10168      13   pittsburgh-steelers      16   NaN
# 10169      23        denver-broncos       9   NaN
# 10170       3    kansas-city-chiefs      35   NaN
# 10171      32      los-angeles-rams      48   NaN
# 10172      24   washington-redskins       0   NaN
# 10173      33      tennessee-titans      17   NaN
# 10174      21        houston-texans       7   NaN
# 10175      22        dallas-cowboys      24   NaN
# 10176      23      baltimore-ravens      17   NaN
# 10177      16         chicago-bears      15   NaN
# 10178      13    kansas-city-chiefs      31   NaN
# 10179      22      los-angeles-rams      30   NaN
# 10180      28  new-england-patriots      41   NaN
# 10181      14    new-orleans-saints      20   NaN
# 10182      26    new-orleans-saints      23    OT
# 10183      37    kansas-city-chiefs      31    OT
# 10184      13      los-angeles-rams       3   NaN
#
# [10185 rows x 8 columns]

# %%
for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
 if (row["team"] == "baltimore-colts"):
    print row
    break
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-171-78993642c734> in <module>()
#       1 for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
# ----> 2  if (row["team"] == "baltimore-colts"):
#       3     print row
#       4     break
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_value(self, series, key)
#    4387                     raise InvalidIndexError(key)
#    4388                 else:
# -> 4389                     raise e1
#    4390             except Exception:  # pragma: no cover
#    4391                 raise e1
#
# KeyError: 'team'

# %% [markdown]
# ---
# **Problem 19:** Give an INSERT command that adds the score of 2012 American Conference Championship (played in 2013) to the Game tables. Use actual data from NFLgames.csv.

# %% [raw]
# INSERT INTO Game
#     VALUES (2012,'Conference Championship',TID,2013-01-20,vTID,28,13,NaN)

# %%
import pandas as pd

dataframe = pd.read_csv("NFLgames.csv")
dataframe
# Out:
#        season                     week        date               visitor  \
# 0        1978                        1  1978-09-02       new-york-giants
# 1        1978                        1  1978-09-03     green-bay-packers
# 2        1978                        1  1978-09-03        houston-oilers
# 3        1978                        1  1978-09-03    kansas-city-chiefs
# 4        1978                        1  1978-09-03      los-angeles-rams
# 5        1978                        1  1978-09-03        miami-dolphins
# 6        1978                        1  1978-09-03     minnesota-vikings
# 7        1978                        1  1978-09-03   pittsburgh-steelers
# 8        1978                        1  1978-09-03   st.-louis-cardinals
# 9        1978                        1  1978-09-03   san-francisco-49ers
# 10       1978                        1  1978-09-03   washington-redskins
# 11       1978                        1  1978-09-03       oakland-raiders
# 12       1978                        1  1978-09-03    san-diego-chargers
# 13       1978                        1  1978-09-04       baltimore-colts
# 14       1978                        2  1978-09-09         detroit-lions
# 15       1978                        2  1978-09-10    cincinnati-bengals
# 16       1978                        2  1978-09-10        dallas-cowboys
# 17       1978                        2  1978-09-10        houston-oilers
# 18       1978                        2  1978-09-10  new-england-patriots
# 19       1978                        2  1978-09-10    new-orleans-saints
# 20       1978                        2  1978-09-10   philadelphia-eagles
# 21       1978                        2  1978-09-10      seattle-seahawks
# 22       1978                        2  1978-09-10       atlanta-falcons
# 23       1978                        2  1978-09-10         chicago-bears
# 24       1978                        2  1978-09-10        miami-dolphins
# 25       1978                        2  1978-09-10         new-york-jets
# 26       1978                        2  1978-09-10       oakland-raiders
# 27       1978                        2  1978-09-11        denver-broncos
# 28       1978                        3  1978-09-17         chicago-bears
# 29       1978                        3  1978-09-17      cleveland-browns
# ...       ...                      ...         ...                   ...
# 10155    2018                       16  2018-12-23   pittsburgh-steelers
# 10156    2018                       16  2018-12-23    kansas-city-chiefs
# 10157    2018                       16  2018-12-24        denver-broncos
# 10158    2018                       17  2018-12-30       atlanta-falcons
# 10159    2018                       17  2018-12-30        miami-dolphins
# 10160    2018                       17  2018-12-30     carolina-panthers
# 10161    2018                       17  2018-12-30        dallas-cowboys
# 10162    2018                       17  2018-12-30         detroit-lions
# 10163    2018                       17  2018-12-30  jacksonville-jaguars
# 10164    2018                       17  2018-12-30         new-york-jets
# 10165    2018                       17  2018-12-30     arizona-cardinals
# 10166    2018                       17  2018-12-30      cleveland-browns
# 10167    2018                       17  2018-12-30         chicago-bears
# 10168    2018                       17  2018-12-30    cincinnati-bengals
# 10169    2018                       17  2018-12-30  los-angeles-chargers
# 10170    2018                       17  2018-12-30       oakland-raiders
# 10171    2018                       17  2018-12-30   san-francisco-49ers
# 10172    2018                       17  2018-12-30   philadelphia-eagles
# 10173    2018                       17  2018-12-30    indianapolis-colts
# 10174    2018        Wild Card Playoff  2019-01-05    indianapolis-colts
# 10175    2018        Wild Card Playoff  2019-01-05      seattle-seahawks
# 10176    2018        Wild Card Playoff  2019-01-06  los-angeles-chargers
# 10177    2018        Wild Card Playoff  2019-01-06   philadelphia-eagles
# 10178    2018       Divisional Playoff  2019-01-12    indianapolis-colts
# 10179    2018       Divisional Playoff  2019-01-12        dallas-cowboys
# 10180    2018       Divisional Playoff  2019-01-13  los-angeles-chargers
# 10181    2018       Divisional Playoff  2019-01-13   philadelphia-eagles
# 10182    2018  Conference Championship  2019-01-20      los-angeles-rams
# 10183    2018  Conference Championship  2019-01-20  new-england-patriots
# 10184    2018               Super Bowl  2019-02-03  new-england-patriots
#
#        vScore                  home  hScore notes
# 0          19  tampa-bay-buccaneers      13   NaN
# 1          13         detroit-lions       7   NaN
# 2          14       atlanta-falcons      20   NaN
# 3          24    cincinnati-bengals      23   NaN
# 4          16   philadelphia-eagles      14   NaN
# 5          20         new-york-jets      33   NaN
# 6          24    new-orleans-saints      31   NaN
# 7          28         buffalo-bills      17   NaN
# 8          10         chicago-bears      17   NaN
# 9           7      cleveland-browns      24   NaN
# 10         16  new-england-patriots      14   NaN
# 11          6        denver-broncos      14   NaN
# 12         24      seattle-seahawks      20   NaN
# 13          0        dallas-cowboys      38   NaN
# 14         15  tampa-bay-buccaneers       7   NaN
# 15         10      cleveland-browns      13    OT
# 16         34       new-york-giants      24   NaN
# 17         20    kansas-city-chiefs      17   NaN
# 18         16   st.-louis-cardinals       6   NaN
# 19         17     green-bay-packers      28   NaN
# 20         30   washington-redskins      35   NaN
# 21         10   pittsburgh-steelers      21   NaN
# 22          0      los-angeles-rams      10   NaN
# 23         16   san-francisco-49ers      13   NaN
# 24         42       baltimore-colts       0   NaN
# 25         21         buffalo-bills      20   NaN
# 26         21    san-diego-chargers      20   NaN
# 27          9     minnesota-vikings      12    OT
# 28         19         detroit-lions       0   NaN
# 29         24       atlanta-falcons      16   NaN
# ...       ...                   ...     ...   ...
# 10155      28    new-orleans-saints      31   NaN
# 10156      31      seattle-seahawks      38   NaN
# 10157      14       oakland-raiders      27   NaN
# 10158      34  tampa-bay-buccaneers      32   NaN
# 10159      17         buffalo-bills      42   NaN
# 10160      33    new-orleans-saints      14   NaN
# 10161      36       new-york-giants      35   NaN
# 10162      31     green-bay-packers       0   NaN
# 10163       3        houston-texans      20   NaN
# 10164       3  new-england-patriots      38   NaN
# 10165      24      seattle-seahawks      27   NaN
# 10166      24      baltimore-ravens      26   NaN
# 10167      24     minnesota-vikings      10   NaN
# 10168      13   pittsburgh-steelers      16   NaN
# 10169      23        denver-broncos       9   NaN
# 10170       3    kansas-city-chiefs      35   NaN
# 10171      32      los-angeles-rams      48   NaN
# 10172      24   washington-redskins       0   NaN
# 10173      33      tennessee-titans      17   NaN
# 10174      21        houston-texans       7   NaN
# 10175      22        dallas-cowboys      24   NaN
# 10176      23      baltimore-ravens      17   NaN
# 10177      16         chicago-bears      15   NaN
# 10178      13    kansas-city-chiefs      31   NaN
# 10179      22      los-angeles-rams      30   NaN
# 10180      28  new-england-patriots      41   NaN
# 10181      14    new-orleans-saints      20   NaN
# 10182      26    new-orleans-saints      23    OT
# 10183      37    kansas-city-chiefs      31    OT
# 10184      13      los-angeles-rams       3   NaN
#
# [10185 rows x 8 columns]

# %%
for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
 if (row["week"] == "Conference Championship"):
    if (row["season"] == 2012):
        print row
# Out:
# season                        2012
# week       Conference Championship
# date                    2013-01-20
# visitor        san-francisco-49ers
# vScore                          28
# home               atlanta-falcons
# hScore                          24
# notes                          NaN
# Name: 8580, dtype: object
# season                        2012
# week       Conference Championship
# date                    2013-01-20
# visitor           baltimore-ravens
# vScore                          28
# home          new-england-patriots
# hScore                          13
# notes                          NaN
# Name: 8581, dtype: object

# %% [markdown]
# ---
# **Problem 20:** Give INSERT commands that add records for 'Jason Myers' to the PlayedFor tables. Use actual data from NFLroster.csv.

# %% [raw]
# INSERT INTO PlayedFor (pid,tid,year,position,jersey,games,starts)
#     VALUES (PID,TID,2015,'K',2,16,0),
#     VALUES (PID,TID,2015,'K',2,16,0),
#     VALUES (PID,TID,2015,'K',2,6,0),
#     VALUES (PID,TID,2015,'K',2,16,0),
#     VALUES (PID,TID,2019,'K',5,0,0)

# %%
import pandas as pd

dataframe = pd.read_csv("NFLrosters.csv")
dataframe
# Out:
#                       team  year jersey               name position height  \
# 0      san-francisco-49ers  1960     --         Dave Baker       DB    6-0
# 1      san-francisco-49ers  1960     --       Bruce Bosley       OG    6-2
# 2      san-francisco-49ers  1960     --        John Brodie       QB    6-1
# 3      san-francisco-49ers  1960     --        Monte Clark       OT    6-6
# 4      san-francisco-49ers  1960     --       Dan Colchico       DE     --
# 5      san-francisco-49ers  1960     --       Clyde Conner       OE    6-2
# 6      san-francisco-49ers  1960     --       Ted Connolly       OG    6-3
# 7      san-francisco-49ers  1960     --        Tommy Davis        K    6-0
# 8      san-francisco-49ers  1960     --         Eddie Dove       DB    6-2
# 9      san-francisco-49ers  1960     --       Bob Harrison       LB    6-2
# 10     san-francisco-49ers  1960     --     Matt Hazeltine       LB    6-1
# 11     san-francisco-49ers  1960     --           Ed Henke       DE    6-3
# 12     san-francisco-49ers  1960     --      Gorden Kelley       LB    6-3
# 13     san-francisco-49ers  1960     --    Charlie Krueger       DT    6-4
# 14     san-francisco-49ers  1960     --        Lenny Lyles       DB    6-2
# 15     san-francisco-49ers  1960     --         Dee Mackey       TE    6-5
# 16     san-francisco-49ers  1960     --         Mike Magac       OG    6-3
# 17     san-francisco-49ers  1960     --     Hugh McElhenny       RB    6-1
# 18     san-francisco-49ers  1960     --      Jerry Mertens       DB    6-0
# 19     san-francisco-49ers  1960     --        Frank Morze        C    6-4
# 20     san-francisco-49ers  1960     --      Leo Nomellini       DT    6-3
# 21     san-francisco-49ers  1960     --         Ray Norton       RB    6-2
# 22     san-francisco-49ers  1960     --     Clancy Osborne       LB    6-3
# 23     san-francisco-49ers  1960     --         R.C. Owens       OE    6-3
# 24     san-francisco-49ers  1960     --          Joe Perry       RB    6-0
# 25     san-francisco-49ers  1960     --       Jimmy Ridlon       DB    6-1
# 26     san-francisco-49ers  1960     --       C.R. Roberts       RB    6-3
# 27     san-francisco-49ers  1960     --          Len Rohde       OT    6-4
# 28     san-francisco-49ers  1960     --         Karl Rubke       LB    6-4
# 29     san-francisco-49ers  1960     --      Henry Schmidt       DT    6-4
# ...                    ...   ...    ...                ...      ...    ...
# 98422    minnesota-vikings  2019     89       David Morgan       TE    6-4
# 98423    minnesota-vikings  2019     72       Storm Norton       OT    6-7
# 98424    minnesota-vikings  2019     75      Brian O'Neill       OT    6-7
# 98425    minnesota-vikings  2019     95    Ifeadi Odenigbo       DE    6-3
# 98426    minnesota-vikings  2019     60      Tito Odenigbo       DT    6-3
# 98427    minnesota-vikings  2019     71        Riley Reiff       OT    6-6
# 98428    minnesota-vikings  2019     29      Xavier Rhodes       DB    6-1
# 98429    minnesota-vikings  2019     82       Kyle Rudolph       TE    6-6
# 98430    minnesota-vikings  2019     62  Anree Saint-Amour       DE    6-3
# 98431    minnesota-vikings  2019     73          Dru Samia       OG    6-5
# 98432    minnesota-vikings  2019     79      Karter Schult       DL    6-3
# 98433    minnesota-vikings  2019      1        Kyle Sloter       QB    6-5
# 98434    minnesota-vikings  2019     59      Cameron Smith       LB    6-2
# 98435    minnesota-vikings  2019     37       Derron Smith       DB   5-10
# 98436    minnesota-vikings  2019     22     Harrison Smith       DB    6-2
# 98437    minnesota-vikings  2019     84          Irv Smith       TE    6-2
# 98438    minnesota-vikings  2019     93     Shamar Stephen       DT    6-5
# 98439    minnesota-vikings  2019     19       Adam Thielen       WR    6-2
# 98440    minnesota-vikings  2019     34        Duke Thomas       DB   5-10
# 98441    minnesota-vikings  2019     11   Laquon Treadwell       WR    6-2
# 98442    minnesota-vikings  2019     74    Olisaemeka Udoh       OT    6-5
# 98443    minnesota-vikings  2019      7       Kaare Vedvik        P    6-3
# 98444    minnesota-vikings  2019     96        Armon Watts       DT    6-5
# 98445    minnesota-vikings  2019     26        Trae Waynes       DB    6-0
# 98446    minnesota-vikings  2019     91  Stephen Weatherly       LB    6-5
# 98447    minnesota-vikings  2019     35     Isaiah Wharton       DB    6-1
# 98448    minnesota-vikings  2019      6          Matt Wile        P    6-2
# 98449    minnesota-vikings  2019     50        Eric Wilson       LB    6-1
# 98450    minnesota-vikings  2019     79       Nate Wozniak       TE   6-10
# 98451    minnesota-vikings  2019     15    Brandon Zylstra       WR    6-2
#
#       weight games starts              college         dob draftYear  \
# 0        192    --     --             Oklahoma  1937-07-30      1959
# 1        241    --     --        West Virginia  1933-11-05      1956
# 2        198    --     --             Stanford  1935-08-14      1957
# 3        265    --     --  Southern California  1937-01-24      1959
# 4         --    --     --       San Jose State          --        --
# 5        193    --     --              Pacific  1933-05-18        --
# 6        240    --     --                Tulsa  1931-12-05      1954
# 7        215    --     --      Louisiana State  1934-10-13      1957
# 8        181    --     --             Colorado  1937-04-04      1959
# 9        225    --     --             Oklahoma  1937-08-08      1959
# 10       220    --     --           California  1933-08-02      1955
# 11       227    --     --  Southern California  1927-12-13      1949
# 12       231    --     --              Georgia  1938-06-11        --
# 13       256    --     --            Texas A&M  1937-01-28      1958
# 14       202    --     --           Louisville  1936-01-26      1958
# 15       235    --     --   Texas A&M-Commerce  1934-10-16      1958
# 16       240    --     --             Missouri  1938-05-25      1960
# 17       195    --     --           Washington  1928-12-31      1952
# 18       184    --     --                Drake  1934-11-12      1958
# 19       270    --     --       Boston College  1933-03-21      1955
# 20       259    --     --            Minnesota  1924-06-19      1950
# 21       184    --     --       San Jose State  1937-09-22      1960
# 22       218    --     --        Arizona State  1934-11-23      1957
# 23       197    --     --     College of Idaho  1934-11-12      1956
# 24       200    --     --      Compton CC (CA)  1927-01-22        --
# 25       181    --     --             Syracuse  1934-07-11      1957
# 26       202    --     --  Southern California  1936-02-29      1958
# 27       247    --     --           Utah State  1938-04-16      1960
# 28       240    --     --  Southern California  1935-12-06      1957
# 29       254    --     --         Trinity (TX)  1935-09-28      1958
# ...      ...   ...    ...                  ...         ...       ...
# 98422    265     0      0    Texas-San Antonio  1993-05-19      2016
# 98423    317     0      0               Toledo  1994-05-16        --
# 98424    297     0      0           Pittsburgh  1995-09-15      2018
# 98425    258     0      0         Northwestern  1994-04-08      2017
# 98426    300     0      0                Miami          --        --
# 98427    305     0      0                 Iowa  1988-12-01      2012
# 98428    218     0      0        Florida State  1990-06-19      2013
# 98429    265     0      0           Notre Dame  1989-11-09      2011
# 98430    245     0      0         Georgia Tech          --        --
# 98431    305     0      0             Oklahoma          --      2019
# 98432    260     0      0        Northern Iowa  1993-12-21        --
# 98433    218     0      0    Northern Colorado  1994-02-07        --
# 98434    238     0      0  Southern California          --      2019
# 98435    200     0      0         Fresno State  1992-02-04      2015
# 98436    214     0      0           Notre Dame  1989-02-02      2012
# 98437    242     0      0              Alabama  1971-10-13      2019
# 98438    309     0      0          Connecticut  1991-02-25      2014
# 98439    200     0      0        Mankato State  1990-08-22        --
# 98440    192     0      0                Texas  1994-05-21        --
# 98441    215     0      0          Mississippi  1995-06-14      2016
# 98442    323     0      0                 Elon          --      2019
# 98443    210     0      0             Marshall  1994-03-16        --
# 98444    300     0      0             Arkansas          --      2019
# 98445    190     0      0       Michigan State  1992-07-25      2015
# 98446    265     0      0           Vanderbilt  1994-03-19      2016
# 98447    205     0      0              Rutgers          --        --
# 98448    225     0      0             Michigan  1992-06-20        --
# 98449    230     0      0           Cincinnati  1994-09-26        --
# 98450    280     0      0            Minnesota  1994-08-30        --
# 98451    215     0      0   Concordia-Moorhead  1993-03-25        --
#
#       draftRound draftOrder            draftTeam
# 0              1          5  san-francisco-49ers
# 1              2         15  san-francisco-49ers
# 2              1          3  san-francisco-49ers
# 3              4         41  san-francisco-49ers
# 4             --         --                   --
# 5             --         --                   --
# 6              9        107  san-francisco-49ers
# 7             11        128  san-francisco-49ers
# 8              3         29  san-francisco-49ers
# 9              2         17  san-francisco-49ers
# 10             4         45  san-francisco-49ers
# 11            13        128  washington-redskins
# 12            --         --                   --
# 13             1          9  san-francisco-49ers
# 14             1         11      baltimore-colts
# 15            24        287  san-francisco-49ers
# 16             2         16  san-francisco-49ers
# 17             1          9  san-francisco-49ers
# 18            20        239  san-francisco-49ers
# 19             2         21  san-francisco-49ers
# 20             1         11  san-francisco-49ers
# 21             4         46  san-francisco-49ers
# 22            27        315     los-angeles-rams
# 23            14        160  san-francisco-49ers
# 24            --         --                   --
# 25             4         39  san-francisco-49ers
# 26            14        166      new-york-giants
# 27             5         59  san-francisco-49ers
# 28             5         56  san-francisco-49ers
# 29             6         71  san-francisco-49ers
# ...          ...        ...                  ...
# 98422          6        188    minnesota-vikings
# 98423         --         --                   --
# 98424          2         62    minnesota-vikings
# 98425          7        220    minnesota-vikings
# 98426         --         --                   --
# 98427          1         23        detroit-lions
# 98428          1         25    minnesota-vikings
# 98429          2         43    minnesota-vikings
# 98430         --         --                   --
# 98431          4        114    minnesota-vikings
# 98432         --         --                   --
# 98433         --         --                   --
# 98434          5        162    minnesota-vikings
# 98435          6        197   cincinnati-bengals
# 98436          1         29    minnesota-vikings
# 98437          2         50    minnesota-vikings
# 98438          7        220    minnesota-vikings
# 98439         --         --                   --
# 98440         --         --                   --
# 98441          1         23    minnesota-vikings
# 98442          6        193    minnesota-vikings
# 98443         --         --                   --
# 98444          6        190    minnesota-vikings
# 98445          1         11    minnesota-vikings
# 98446          7        227    minnesota-vikings
# 98447         --         --                   --
# 98448         --         --                   --
# 98449         --         --                   --
# 98450         --         --                   --
# 98451         --         --                   --
#
# [98452 rows x 15 columns]

# %%
for index, row in dataframe.iterrows(): # index is a number, row is a dictionary
 if (row["name"] == "Jason Myers"):
        print row
# Out:
# team          jacksonville-jaguars
# year                          2015
# jersey                           2
# name                   Jason Myers
# position                         K
# height                        5-10
# weight                         180
# games                           16
# starts                           0
# college                     Marist
# dob                     1991-05-12
# draftYear                       --
# draftRound                      --
# draftOrder                      --
# draftTeam                       --
# Name: 54086, dtype: object
# team          jacksonville-jaguars
# year                          2016
# jersey                           2
# name                   Jason Myers
# position                         K
# height                        5-10
# weight                         180
# games                           16
# starts                           0
# college                     Marist
# dob                     1991-05-12
# draftYear                       --
# draftRound                      --
# draftOrder                      --
# draftTeam                       --
# Name: 54148, dtype: object
# team          jacksonville-jaguars
# year                          2017
# jersey                           2
# name                   Jason Myers
# position                         K
# height                        5-10
# weight                         180
# games                            6
# starts                           0
# college                     Marist
# dob                     1991-05-12
# draftYear                       --
# draftRound                      --
# draftOrder                      --
# draftTeam                       --
# Name: 54212, dtype: object
# team          new-york-jets
# year                   2018
# jersey                    2
# name            Jason Myers
# position                  K
# height                 5-10
# weight                  180
# games                    16
# starts                    0
# college              Marist
# dob              1991-05-12
# draftYear                --
# draftRound               --
# draftOrder               --
# draftTeam                --
# Name: 57710, dtype: object
# team          seattle-seahawks
# year                      2019
# jersey                       5
# name               Jason Myers
# position                     K
# height                    5-10
# weight                     190
# games                        0
# starts                       0
# college                 Marist
# dob                 1991-05-12
# draftYear                   --
# draftRound                  --
# draftOrder                  --
# draftTeam                   --
# Name: 87339, dtype: object

# %% [markdown]
# Click [here to submit](http://csbio.unc.edu/mcmillan/index.py?run=PS.upload) your completed problem set.
#
# You can submit it as many times as you would like, but only the last submitted version will be graded. If the last submission was after the due date the final score will be reduced accordingly.
